# %% [markdown]
# ## Getting the Data <a class="anchor" id="Getting the Data"></a>
#
# We first going to gather the data needed for this project. We are going to extract the words in each Wikipedia page to understand the relation between each physicist and physics domain.

# %%
## We get the nobel data set
import numpy as np
import pandas as pd
from httplib2 import Http
from bs4 import BeautifulSoup, SoupStrainer
import requests

class Parser:
    
    def __init__(self, url):  
        http = Http()
        status, response = http.request(url)
        tables = BeautifulSoup(response, "lxml", 
                              parse_only=SoupStrainer("table", {"class":"wikitable sortable"}))
        self.table = tables.contents[1]
    
    def parse_table(self):      
        rows = self.table.find_all("tr")
        header = self.parse_header(rows[0])
        table_array = [self.parse_row(row) for row in rows[1:]]
        table_df = pd.DataFrame(table_array, columns=header).apply(self.clean_table, 1)
        return table_df.replace({"Year":{'':np.nan}})
        
    def parse_row(self, row):     
        columns = row.find_all("td")
        return [BeautifulSoup.get_text(col).strip() for col in columns if BeautifulSoup.get_text(col) != '']
    
    def parse_header(self, row):     
        columns = row.find_all("th")
        return [BeautifulSoup.get_text(col).strip() for col in columns if BeautifulSoup.get_text(col) != ""]
    
    def clean_table(self, row):
        if not row.iloc[0].isdigit() and row.iloc[0] != '':
            return row.shift(1)
        else:
            return row
        
url = "https://en.wikipedia.org/wiki/List_of_Nobel_laureates_in_Physics"        
parser = Parser(url)   
nobel_df = parser.parse_table()
nobel_df.columns = ["Year", "Laureate", "Country", "Rationale"]
nobel_df.dropna(subset=["Country"], inplace=True)
nobel_df.fillna(method="ffill", inplace=True)
nobel_df.drop(["Year", "Country", "Rationale"], 1, inplace=True)

http = Http()
status, response = http.request(url)

table = BeautifulSoup(response, "lxml", parse_only=SoupStrainer('table'))
link_df = pd.DataFrame([[x.string, x["href"]] for x in table.contents[1].find_all("a")],
                       columns=["Laureate", "link"]).drop_duplicates()

nobel_df = nobel_df.merge(link_df, on="Laureate", how="left")
nobel_df.set_index("Laureate", inplace=True)
nobel_df.drop_duplicates(inplace=True)
nobel_df

# %% [markdown]
# We also going to extract the links of each of the physics domains listed in the Research fields table of the [https://en.wikipedia.org/wiki/Physics](https://en.wikipedia.org/wiki/Physics) Wikipedia page.

# %%
## We get the physics links
url = "https://en.wikipedia.org/wiki/Physics"

http = Http()
status, response = http.request(url)

table = BeautifulSoup(response, "lxml", parse_only=SoupStrainer('table'))
physics_df = pd.DataFrame([[x.string.lower(), x["href"].lower()] for x in table.contents[2].find_all("a")],
                       columns=["Physics_domain", "link"]).drop_duplicates()

physics_df = physics_df.groupby("Physics_domain").first()
physics_df
# Out:
#                                                                                      link
# Physics_domain
# 't hooft                                                          /wiki/gerard_%27t_hooft
# albert einstein                                                     /wiki/albert_einstein
# antimatter                                                               /wiki/antimatter
# antiparticle                                                           /wiki/antiparticle
# applied                                                             /wiki/applied_physics
# astrophysics                                                           /wiki/astrophysics
# atomic physics                                                       /wiki/atomic_physics
# atomic, molecular, and optical physics       /wiki/atomic,_molecular,_and_optical_physics
# bardeen                                                                /wiki/john_bardeen
# becquerel                                                           /wiki/henri_becquerel
# bell                                                              /wiki/john_stewart_bell
# big bang                                                                   /wiki/big_bang
# biophysics                                                               /wiki/biophysics
# black holes                                                              /wiki/black_hole
# bohr                                                                     /wiki/niels_bohr
# born                                                                       /wiki/max_born
# bose                                                            /wiki/satyendra_nath_bose
# bragg                                                                /wiki/lawrence_bragg
# chadwick                                                             /wiki/james_chadwick
# complex systems                                                      /wiki/complex_system
# compton                                                              /wiki/arthur_compton
# condensed matter physics                                   /wiki/condensed_matter_physics
# cosmology                                                                 /wiki/cosmology
# curie                                                                  /wiki/pierre_curie
# dark energy                                                             /wiki/dark_energy
# dark matter                                                             /wiki/dark_matter
# de broglie                                                         /wiki/louis_de_broglie
# dirac                                                                    /wiki/paul_dirac
# dyson                                                                 /wiki/freeman_dyson
# e                                       //en.wikipedia.org/w/index.php?title=template:...
# ...                                                                                   ...
# spintronics                                                             /wiki/spintronics
# standard model                                                       /wiki/standard_model
# string theory                                                         /wiki/string_theory
# strong interaction                                               /wiki/strong_interaction
# superconductivity                                                 /wiki/superconductivity
# supersymmetry                                                         /wiki/supersymmetry
# t                                                      /wiki/template_talk:modern_physics
# theoretical                                                     /wiki/theoretical_physics
# theories of gravitation                                     /wiki/theories_of_gravitation
# theory of everything                                           /wiki/theory_of_everything
# thomson                                                    /wiki/sir_george_paget_thomson
# time                                                                           /wiki/time
# topology                                                         /wiki/spacetime_topology
# v                                                           /wiki/template:modern_physics
# van der waals                                        /wiki/johannes_diderik_van_der_waals
# von neumann                                                        /wiki/john_von_neumann
# walton                                                                /wiki/ernest_walton
# wave                                                                           /wiki/wave
# weak gravity conjecture                                     /wiki/weak_gravity_conjecture
# weak interaction                                                   /wiki/weak_interaction
# werner heisenberg                                                 /wiki/werner_heisenberg
# weyl                                                                   /wiki/hermann_weyl
# wheeler                                                      /wiki/john_archibald_wheeler
# wien                                                                   /wiki/wilhelm_wien
# wigner                                                                /wiki/eugene_wigner
# wilczek                                                               /wiki/frank_wilczek
# wolfgang pauli                                                       /wiki/wolfgang_pauli
# work                                                                 /wiki/work_(physics)
# zeeman                                                                /wiki/pieter_zeeman
# zeilinger                                                           /wiki/anton_zeilinger
#
# [155 rows x 1 columns]

# %% [markdown]
# ## Cleaning the data <a class="anchor" id="Cleaning the data"></a>
#
# >Use the code from your previous homework to create the different functions to clean the get the word data and clean it.

# %%
from string import punctuation

## We get the bios
def get_text(link, root_website = "https://en.wikipedia.org"):    
    http = Http()
    status, response = http.request(root_website + link)
    body = BeautifulSoup(response, "lxml", parse_only=SoupStrainer("div", {"id":"mw-content-text"}))
    return BeautifulSoup.get_text(body.contents[1])

# TODO: copy your clean_string function from the previous homework
def clean_string(string):
    for p in punctuation + "1234567890":
        string = string.replace(p,'').lower()   
    return string

# TODO: copy your remove function from the previous homework
def remove(list_to_clean, element_to_remove=[None, ""]):
    return list(filter(lambda x: x != element_to_remove, list_to_clean))

# TODO: copy your remove_one function from the previous homework
def remove_one(list_to_clean):
    return list(filter(lambda x: len(x) > 1, list_to_clean))

# %% [markdown]
# We now going to write a function that takes a data frame with a "link" column and return a column of list of words. We basically aggregate all the above function into one to reproduce what was done in the previous homework. Note that here we DO NOT use the function that keep only a unique element of each list nor the one that filter on the number of occurance.
#
# > Write a function that applies all the previous functions to clean a text.

# %%
from nltk.corpus import stopwords
words_to_remove = set(stopwords.words('english'))

#remove stopwords
def remove_stopword(list_to_clean, remove_list = words_to_remove):
    return list(filter(lambda x: x not in remove_list, list_to_clean))

# TODO: aggregate all the above function into one to return a list of words from each link
def clean_everything(df):
    return df['link'].apply(get_text) \
            .apply(clean_string) \
            .str.split() \
            .apply(remove) \
            .apply(remove_one) \
            .apply(remove_stopword)

    
    
physics_df["physics_list"] = clean_everything(physics_df)
nobel_df["physics_list"] = clean_everything(nobel_df)
nobel_df
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\Anaconda3\envs\dscsulb\lib\site-packages\nltk\corpus\util.py in __load(self)
#      85                 try:
# ---> 86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
#
# ~\Anaconda3\envs\dscsulb\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Attempted to load corpora/stopwords.zip/stopwords/
#
#   Searched in:
#     - 'C:\\Users\\Bob/nltk_data'
#     - 'C:\\Users\\Bob\\Anaconda3\\envs\\dscsulb\\nltk_data'
#     - 'C:\\Users\\Bob\\Anaconda3\\envs\\dscsulb\\share\\nltk_data'
#     - 'C:\\Users\\Bob\\Anaconda3\\envs\\dscsulb\\lib\\nltk_data'
#     - 'C:\\Users\\Bob\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-56-1dd19ffabe4d> in <module>()
#       1 from nltk.corpus import stopwords
# ----> 2 words_to_remove = set(stopwords.words('english'))
#       3
#       4 #remove stopwords
#       5 def remove_stopword(list_to_clean, remove_list = words_to_remove):
#
# ~\Anaconda3\envs\dscsulb\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     121             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     122
# --> 123         self.__load()
#     124         # This looks circular, but its not, since __load() changes our
#     125         # __class__ to something new:
#
# ~\Anaconda3\envs\dscsulb\lib\site-packages\nltk\corpus\util.py in __load(self)
#      86                     root = nltk.data.find('{}/{}'.format(self.subdir, zip_name))
#      87                 except LookupError:
# ---> 88                     raise e
#      89
#      90         # Load the corpus.
#
# ~\Anaconda3\envs\dscsulb\lib\site-packages\nltk\corpus\util.py in __load(self)
#      81         else:
#      82             try:
# ---> 83                 root = nltk.data.find('{}/{}'.format(self.subdir, self.__name))
#      84             except LookupError as e:
#      85                 try:
#
# ~\Anaconda3\envs\dscsulb\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     697     sep = '*' * 70
#     698     resource_not_found = '\n%s\n%s\n%s\n' % (sep, msg, sep)
# --> 699     raise LookupError(resource_not_found)
#     700
#     701
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   Attempted to load corpora/stopwords
#
#   Searched in:
#     - 'C:\\Users\\Bob/nltk_data'
#     - 'C:\\Users\\Bob\\Anaconda3\\envs\\dscsulb\\nltk_data'
#     - 'C:\\Users\\Bob\\Anaconda3\\envs\\dscsulb\\share\\nltk_data'
#     - 'C:\\Users\\Bob\\Anaconda3\\envs\\dscsulb\\lib\\nltk_data'
#     - 'C:\\Users\\Bob\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %% [markdown]
# We saw last time that there are many words that are not relevant to physics concepts in those Wikipedia pages. We are going to attempt to filter those with the simple following approach.
#
# We are going to compile a set of all the unique words in the `nobel_df` lists and a set of all the unique words in the `physics_df` lists. By taking the intersection of those 2 sets, we can subset the words corpus to something more relevant to physics.
#
# >- Compile a set of all unique words in `nobel_df["physics_list"]`. You can use the function [`pd.sum`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sum.html) to concatenate lists. You can cast the final list to a [`set`](https://docs.python.org/2/library/sets.html)
# - Compile a set of all unique words in `physics_df["physics_list"]`.
# - Compile the intersection of those 2 sets using the `intersection` function.

# %%
# TODO: find all the words in nobel_df["physics_list"]
all_nobel_words =  set(nobel_df['physics_list'].sum())

# TODO: find all the words in physics_df["physics_list"]
all_physics_words =  set(physics_df['physics_list'].sum())

# TODO: find all the intersection of all_nobel_words and all_physics_words
physics_corpus =  set(all_nobel_words.intersection(all_physics_words))

physics_corpus
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-57-7efc8c0faa55> in <module>()
#       1 # TODO: find all the words in nobel_df["physics_list"]
# ----> 2 all_nobel_words =  set(nobel_df['physics_list'].sum())
#       3
#       4 # TODO: find all the words in physics_df["physics_list"]
#       5 all_physics_words =  set(physics_df['physics_list'].sum())
#
# NameError: name 'nobel_df' is not defined

# %%
#Checking intersection list length
print(len(physics_corpus), len(all_nobel_words), len(all_physics_words))
# Out:
# 12725 31370 33494

# %% [markdown]
# >Write a function that keep only specific words from a list

# %%
# TODO: write a function that keep only specific words from a list
def keep_only(list_to_clean, corpus=physics_corpus):
    return list(filter(lambda x: x in corpus, list_to_clean))
    
nobel_df["physics_list_clean"] = nobel_df["physics_list"].apply(keep_only)
physics_df["physics_list_clean"] = physics_df["physics_list"].apply(keep_only)

# %% [markdown]
# ## Compiling the nodes data <a class="anchor" id="Compiling the nodes data"></a>
#
# For those 2 dataframes, we are going to create 2 additional columns:
#
# >- create columns "length" that counts the number of words in each list. This column will be used to capture the size of the nodes in the networks. Basically we are going to say: the more words in the Wikipedia page, the more significant the physicist or physics domain is.
# - create columns "group" with a unique value for each of those dataframes. Set the value to 1 in the `nobel_df` dataframe and 0 for the `physics_df` dataframe. This columns will be used to distinguish the physicists from the physics domains and attribute them different colors in the network visualization.

# %%
# TODO: compute the length of each list
nobel_df["length"] =  nobel_df['physics_list_clean'].apply(len)
physics_df["length"] =  physics_df['physics_list_clean'].apply(len)

# TODO: Set this column to 1
nobel_df["group"] =  1
# TODO: Set this column to 0 
physics_df["group"] =  0

# %% [markdown]
# Let's concatenate the those 2 dataframes into the `nodes_df` dataframe.
#
# >Use the [`pd.concat`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.concat.html) function to do so and only keep the "length" and "group" columns. The concatenation needs to be done along the row axis.

# %%
# TODO: concatenate those two dataframe into the nodes_df dataframe. 
# keep only the "length" and "group" columns.
nodes_df =   pd.concat([nobel_df[['length', 'group']], physics_df[['length','group']]], axis=0)

nodes_df.index.name = "id"

# %% [markdown]
# From this dataframe, we can easily format the data as a list of dictionaries as the d3.js library expects the data to be. We have the "length" attribute for the size of the node, the "group" attribute to distinguish between physicists and physics domains and each node has a unique "id" tag represented by the names.

# %%
nodes_list = list(nodes_df.reset_index().transpose().to_dict().values())
nodes_list
# Out:
# [{'group': 1, 'id': 'Wilhelm Conrad Röntgen', 'length': 1293},
#  {'group': 1, 'id': 'Hendrik Lorentz', 'length': 2745},
#  {'group': 1, 'id': 'Pieter Zeeman', 'length': 986},
#  {'group': 1, 'id': 'Antoine Henri Becquerel', 'length': 1159},
#  {'group': 1, 'id': 'Pierre Curie', 'length': 1432},
#  {'group': 1, 'id': 'Maria Skłodowska-Curie', 'length': 4966},
#  {'group': 1, 'id': 'Lord Rayleigh', 'length': 1418},
#  {'group': 1, 'id': 'Philipp Eduard Anton von Lenard', 'length': 1258},
#  {'group': 1, 'id': 'Joseph John Thomson', 'length': 2901},
#  {'group': 1, 'id': 'Albert Abraham Michelson', 'length': 2306},
#  {'group': 1, 'id': 'Gabriel Lippmann', 'length': 1472},
#  {'group': 1, 'id': 'Guglielmo Marconi', 'length': 4085},
#  {'group': 1, 'id': 'Karl Ferdinand Braun', 'length': 840},
#  {'group': 1, 'id': 'Johannes Diderik van der Waals', 'length': 2188},
#  {'group': 1, 'id': 'Wilhelm Wien', 'length': 747},
#  {'group': 1, 'id': 'Nils Gustaf Dalén', 'length': 779},
#  {'group': 1, 'id': 'Heike Kamerlingh-Onnes', 'length': 1185},
#  {'group': 1, 'id': 'Max von Laue', 'length': 2397},
#  {'group': 1, 'id': 'William Henry Bragg', 'length': 1529},
#  {'group': 1, 'id': 'William Lawrence Bragg', 'length': 1475},
#  {'group': 1, 'id': 'Charles Glover Barkla', 'length': 541},
#  {'group': 1, 'id': 'Max Planck', 'length': 3148},
#  {'group': 1, 'id': 'Johannes Stark', 'length': 919},
#  {'group': 1, 'id': 'Charles Édouard Guillaume', 'length': 505},
#  {'group': 1, 'id': 'Albert Einstein', 'length': 8939},
#  {'group': 1, 'id': 'Niels Bohr', 'length': 5046},
#  {'group': 1, 'id': 'Robert Andrews Millikan', 'length': 2336},
#  {'group': 1, 'id': 'Manne Siegbahn', 'length': 518},
#  {'group': 1, 'id': 'James Franck', 'length': 2280},
#  {'group': 1, 'id': 'Gustav Hertz', 'length': 1047},
#  {'group': 1, 'id': 'Jean Baptiste Perrin', 'length': 889},
#  {'group': 1, 'id': 'Arthur Holly Compton', 'length': 2648},
#  {'group': 1, 'id': 'Charles Thomson Rees Wilson', 'length': 1023},
#  {'group': 1, 'id': 'Owen Willans Richardson', 'length': 544},
#  {'group': 1,
#   'id': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'length': 1833},
#  {'group': 1, 'id': 'Chandrasekhara Venkata Raman', 'length': 1911},
#  {'group': 1, 'id': 'Werner Heisenberg', 'length': 6460},
#  {'group': 1, 'id': 'Erwin Schrödinger', 'length': 2280},
#  {'group': 1, 'id': 'Paul Dirac', 'length': 3775},
#  {'group': 1, 'id': 'James Chadwick', 'length': 3966},
#  {'group': 1, 'id': 'Victor Francis Hess', 'length': 642},
#  {'group': 1, 'id': 'Carl David Anderson', 'length': 617},
#  {'group': 1, 'id': 'Clinton Joseph Davisson', 'length': 618},
#  {'group': 1, 'id': 'George Paget Thomson', 'length': 568},
#  {'group': 1, 'id': 'Enrico Fermi', 'length': 5850},
#  {'group': 1, 'id': 'Ernest Lawrence', 'length': 3701},
#  {'group': 1, 'id': 'Otto Stern', 'length': 514},
#  {'group': 1, 'id': 'Isidor Isaac Rabi', 'length': 3593},
#  {'group': 1, 'id': 'Wolfgang Pauli', 'length': 1879},
#  {'group': 1, 'id': 'Percy Williams Bridgman', 'length': 1196},
#  {'group': 1, 'id': 'Edward Victor Appleton', 'length': 1549},
#  {'group': 1, 'id': 'Patrick Maynard Stuart Blackett', 'length': 1656},
#  {'group': 1, 'id': 'Hideki Yukawa', 'length': 722},
#  {'group': 1, 'id': 'Cecil Frank Powell', 'length': 885},
#  {'group': 1, 'id': 'John Douglas Cockcroft', 'length': 2950},
#  {'group': 1, 'id': 'Ernest Thomas Sinton Walton', 'length': 1036},
#  {'group': 1, 'id': 'Felix Bloch', 'length': 1052},
#  {'group': 1, 'id': 'Edward Mills Purcell', 'length': 919},
#  {'group': 1, 'id': 'Frits Zernike', 'length': 679},
#  {'group': 1, 'id': 'Max Born', 'length': 3507},
#  {'group': 1, 'id': 'Walther Bothe', 'length': 2014},
#  {'group': 1, 'id': 'Willis Eugene Lamb', 'length': 607},
#  {'group': 1, 'id': 'Polykarp Kusch', 'length': 450},
#  {'group': 1, 'id': 'John Bardeen', 'length': 2384},
#  {'group': 1, 'id': 'Walter Houser Brattain', 'length': 1706},
#  {'group': 1, 'id': 'William Bradford Shockley', 'length': 2758},
#  {'group': 1, 'id': 'Tsung-Dao Lee', 'length': 1638},
#  {'group': 1, 'id': 'Chen Ning Yang', 'length': 2162},
#  {'group': 1, 'id': 'Pavel Alekseyevich Cherenkov', 'length': 484},
#  {'group': 1, 'id': 'Ilya Frank', 'length': 551},
#  {'group': 1, 'id': 'Igor Yevgenyevich Tamm', 'length': 726},
#  {'group': 1, 'id': 'Emilio Gino Segrè', 'length': 2556},
#  {'group': 1, 'id': 'Owen Chamberlain', 'length': 658},
#  {'group': 1, 'id': 'Donald Arthur Glaser', 'length': 1148},
#  {'group': 1, 'id': 'Robert Hofstadter', 'length': 891},
#  {'group': 1, 'id': 'Rudolf Ludwig Mössbauer', 'length': 581},
#  {'group': 1, 'id': 'Lev Davidovich Landau', 'length': 1792},
#  {'group': 1, 'id': 'Eugene Paul Wigner', 'length': 3560},
#  {'group': 1, 'id': 'Maria Goeppert-Mayer', 'length': 2147},
#  {'group': 1, 'id': 'J. Hans D. Jensen', 'length': 940},
#  {'group': 1, 'id': 'Nicolay Gennadiyevich Basov', 'length': 573},
#  {'group': 1, 'id': 'Alexander Prokhorov', 'length': 932},
#  {'group': 1, 'id': 'Charles Hard Townes', 'length': 2192},
#  {'group': 1, 'id': 'Richard Phillips Feynman', 'length': 6482},
#  {'group': 1, 'id': 'Julian Schwinger', 'length': 1532},
#  {'group': 1, 'id': 'Sin-Itiro Tomonaga', 'length': 683},
#  {'group': 1, 'id': 'Alfred Kastler', 'length': 496},
#  {'group': 1, 'id': 'Hans Albrecht Bethe', 'length': 4144},
#  {'group': 1, 'id': 'Luis Walter Alvarez', 'length': 4327},
#  {'group': 1, 'id': 'Murray Gell-Mann', 'length': 1516},
#  {'group': 1, 'id': 'Hannes Olof Gösta Alfvén', 'length': 1636},
#  {'group': 1, 'id': 'Louis Néel', 'length': 721},
#  {'group': 1, 'id': 'Dennis Gabor', 'length': 1151},
#  {'group': 1, 'id': 'Leon Neil Cooper', 'length': 654},
#  {'group': 1, 'id': 'John Robert Schrieffer', 'length': 873},
#  {'group': 1, 'id': 'Leo Esaki', 'length': 902},
#  {'group': 1, 'id': 'Ivar Giaever', 'length': 1161},
#  {'group': 1, 'id': 'Brian David Josephson', 'length': 3463},
#  {'group': 1, 'id': 'Martin Ryle', 'length': 1258},
#  {'group': 1, 'id': 'Antony Hewish', 'length': 725},
#  {'group': 1, 'id': 'Aage Bohr', 'length': 1643},
#  {'group': 1, 'id': 'Ben Roy Mottelson', 'length': 532},
#  {'group': 1, 'id': 'Leo James Rainwater', 'length': 1063},
#  {'group': 1, 'id': 'Burton Richter', 'length': 980},
#  {'group': 1, 'id': 'Samuel Chao Chung Ting', 'length': 1085},
#  {'group': 1, 'id': 'Philip Warren Anderson', 'length': 1086},
#  {'group': 1, 'id': 'Nevill Francis Mott', 'length': 1414},
#  {'group': 1, 'id': 'John Hasbrouck Van Vleck', 'length': 1250},
#  {'group': 1, 'id': 'Pyotr Leonidovich Kapitsa', 'length': 826},
#  {'group': 1, 'id': 'Arno Allan Penzias', 'length': 885},
#  {'group': 1, 'id': 'Robert Woodrow Wilson', 'length': 614},
#  {'group': 1, 'id': 'Sheldon Lee Glashow', 'length': 824},
#  {'group': 1, 'id': 'Abdus Salam', 'length': 5491},
#  {'group': 1, 'id': 'Steven Weinberg', 'length': 1776},
#  {'group': 1, 'id': 'James Watson Cronin', 'length': 1028},
#  {'group': 1, 'id': 'Val Logsdon Fitch', 'length': 2401},
#  {'group': 1, 'id': 'Nicolaas Bloembergen', 'length': 1225},
#  {'group': 1, 'id': 'Arthur Leonard Schawlow', 'length': 900},
#  {'group': 1, 'id': 'Kai Manne Börje Siegbahn', 'length': 380},
#  {'group': 1, 'id': 'Kenneth G. Wilson', 'length': 1111},
#  {'group': 1, 'id': 'Subrahmanyan Chandrasekhar', 'length': 2795},
#  {'group': 1, 'id': 'William Alfred Fowler', 'length': 849},
#  {'group': 1, 'id': 'Carlo Rubbia', 'length': 1167},
#  {'group': 1, 'id': 'Simon van der Meer', 'length': 894},
#  {'group': 1, 'id': 'Klaus von Klitzing', 'length': 624},
#  {'group': 1, 'id': 'Ernst Ruska', 'length': 457},
#  {'group': 1, 'id': 'Gerd Binnig', 'length': 648},
#  {'group': 1, 'id': 'Heinrich Rohrer', 'length': 480},
#  {'group': 1, 'id': 'Johannes Georg Bednorz', 'length': 563},
#  {'group': 1, 'id': 'Karl Alexander Müller', 'length': 681},
#  {'group': 1, 'id': 'Leon Max Lederman', 'length': 2105},
#  {'group': 1, 'id': 'Melvin Schwartz', 'length': 549},
#  {'group': 1, 'id': 'Jack Steinberger', 'length': 1240},
#  {'group': 1, 'id': 'Norman Foster Ramsey', 'length': 2764},
#  {'group': 1, 'id': 'Hans Georg Dehmelt', 'length': 565},
#  {'group': 1, 'id': 'Wolfgang Paul', 'length': 516},
#  {'group': 1, 'id': 'Jerome I. Friedman', 'length': 818},
#  {'group': 1, 'id': 'Henry Way Kendall', 'length': 780},
#  {'group': 1, 'id': 'Richard E. Taylor', 'length': 677},
#  {'group': 1, 'id': 'Pierre-Gilles de Gennes', 'length': 708},
#  {'group': 1, 'id': 'Georges Charpak', 'length': 797},
#  {'group': 1, 'id': 'Russell Alan Hulse', 'length': 737},
#  {'group': 1, 'id': 'Joseph Hooton Taylor, Jr.', 'length': 1161},
#  {'group': 1, 'id': 'Bertram Brockhouse', 'length': 538},
#  {'group': 1, 'id': 'Clifford Glenwood Shull', 'length': 861},
#  {'group': 1, 'id': 'Martin Lewis Perl', 'length': 961},
#  {'group': 1, 'id': 'Frederick Reines', 'length': 2454},
#  {'group': 1, 'id': 'David Morris Lee', 'length': 624},
#  {'group': 1, 'id': 'Douglas D. Osheroff', 'length': 671},
#  {'group': 1, 'id': 'Robert Coleman Richardson', 'length': 532},
#  {'group': 1, 'id': 'Steven Chu', 'length': 2307},
#  {'group': 1, 'id': 'Claude Cohen-Tannoudji', 'length': 696},
#  {'group': 1, 'id': 'William Daniel Phillips', 'length': 587},
#  {'group': 1, 'id': 'Robert B. Laughlin', 'length': 605},
#  {'group': 1, 'id': 'Horst Ludwig Störmer', 'length': 531},
#  {'group': 1, 'id': 'Daniel Chee Tsui', 'length': 572},
#  {'group': 1, 'id': "Gerard 't Hooft", 'length': 1913},
#  {'group': 1, 'id': 'Martinus J. G. Veltman', 'length': 747},
#  {'group': 1, 'id': 'Zhores Ivanovich Alferov', 'length': 980},
#  {'group': 1, 'id': 'Herbert Kroemer', 'length': 600},
#  {'group': 1, 'id': 'Jack St. Clair Kilby', 'length': 1864},
#  {'group': 1, 'id': 'Eric Allin Cornell', 'length': 622},
#  {'group': 1, 'id': 'Carl Edwin Wieman', 'length': 703},
#  {'group': 1, 'id': 'Wolfgang Ketterle', 'length': 742},
#  {'group': 1, 'id': 'Raymond Davis, Jr.', 'length': 993},
#  {'group': 1, 'id': 'Masatoshi Koshiba', 'length': 840},
#  {'group': 1, 'id': 'Riccardo Giacconi', 'length': 626},
#  {'group': 1, 'id': 'Alexei Alexeyevich Abrikosov', 'length': 812},
#  {'group': 1, 'id': 'Vitaly Lazarevich Ginzburg', 'length': 1030},
#  {'group': 1, 'id': 'Anthony James Leggett', 'length': 1204},
#  {'group': 1, 'id': 'David J. Gross', 'length': 1432},
#  {'group': 1, 'id': 'Hugh David Politzer', 'length': 531},
#  {'group': 1, 'id': 'Frank Wilczek', 'length': 1189},
#  {'group': 1, 'id': 'Roy J. Glauber', 'length': 792},
#  {'group': 1, 'id': 'John L. Hall', 'length': 665},
#  {'group': 1, 'id': 'Theodor W. Hänsch', 'length': 902},
#  {'group': 1, 'id': 'John C. Mather', 'length': 1138},
#  {'group': 1, 'id': 'George F. Smoot', 'length': 1611},
#  {'group': 1, 'id': 'Albert Fert', 'length': 695},
#  {'group': 1, 'id': 'Peter Grünberg', 'length': 868},
#  {'group': 1, 'id': 'Makoto Kobayashi', 'length': 667},
#  {'group': 1, 'id': 'Toshihide Maskawa', 'length': 588},
#  {'group': 1, 'id': 'Yoichiro Nambu', 'length': 1663},
#  {'group': 1, 'id': 'Charles K. Kao', 'length': 4038},
#  {'group': 1, 'id': 'Willard S. Boyle', 'length': 725},
#  {'group': 1, 'id': 'George E. Smith', 'length': 555},
#  {'group': 1, 'id': 'Andre Geim', 'length': 2174},
#  {'group': 1, 'id': 'Konstantin Novoselov', 'length': 1396},
#  {'group': 1, 'id': 'Saul Perlmutter', 'length': 1390},
#  {'group': 1, 'id': 'Brian P. Schmidt', 'length': 2271},
#  {'group': 1, 'id': 'Adam G. Riess', 'length': 1196},
#  {'group': 1, 'id': 'Serge Haroche', 'length': 878},
#  {'group': 1, 'id': 'David J. Wineland', 'length': 1516},
#  {'group': 1, 'id': 'François Englert', 'length': 1160},
#  {'group': 1, 'id': 'Peter Higgs', 'length': 2519},
#  {'group': 1, 'id': 'Isamu Akasaki', 'length': 1262},
#  {'group': 1, 'id': 'Hiroshi Amano', 'length': 606},
#  {'group': 1, 'id': 'Shuji Nakamura', 'length': 928},
#  {'group': 1, 'id': 'Takaaki Kajita', 'length': 977},
#  {'group': 1, 'id': 'Arthur B. McDonald', 'length': 995},
#  {'group': 1, 'id': 'David J. Thouless', 'length': 963},
#  {'group': 1, 'id': 'F. Duncan M. Haldane', 'length': 760},
#  {'group': 1, 'id': 'John M. Kosterlitz', 'length': 619},
#  {'group': 1, 'id': 'Rainer Weiss', 'length': 1803},
#  {'group': 1, 'id': 'Kip Thorne', 'length': 2821},
#  {'group': 1, 'id': 'Barry Barish', 'length': 1386},
#  {'group': 0, 'id': 'accelerator physics', 'length': 856},
#  {'group': 0, 'id': 'acoustics', 'length': 2055},
#  {'group': 0, 'id': 'agrophysics', 'length': 399},
#  {'group': 0, 'id': 'antimatter', 'length': 3415},
#  {'group': 0, 'id': 'applied physics', 'length': 283},
#  {'group': 0, 'id': 'astrometry', 'length': 1142},
#  {'group': 0, 'id': 'astronomy', 'length': 5177},
#  {'group': 0, 'id': 'astrophysics', 'length': 1973},
#  {'group': 0, 'id': 'atom', 'length': 6606},
#  {'group': 0, 'id': 'atomic and molecular astrophysics', 'length': 490},
#  {'group': 0, 'id': 'atomic physics', 'length': 1022},
#  {'group': 0, 'id': 'atomic, molecular, and optical physics', 'length': 1816},
#  {'group': 0, 'id': 'bcs theory', 'length': 1335},
#  {'group': 0, 'id': 'big bang', 'length': 6917},
#  {'group': 0, 'id': 'biophysics', 'length': 889},
#  {'group': 0, 'id': 'black hole', 'length': 7889},
#  {'group': 0, 'id': 'bloch wave', 'length': 833},
#  {'group': 0, 'id': 'bose-einstein condensate', 'length': 3369},
#  {'group': 0, 'id': 'brane', 'length': 105},
#  {'group': 0, 'id': 'casimir effect', 'length': 3135},
#  {'group': 0, 'id': 'chemical physics', 'length': 489},
#  {'group': 0, 'id': 'communication physics', 'length': 253},
#  {'group': 0, 'id': 'condensed matter physics', 'length': 3477},
#  {'group': 0, 'id': 'cosmic background radiation', 'length': 446},
#  {'group': 0, 'id': 'cosmic inflation', 'length': 6265},
#  {'group': 0, 'id': 'cosmic string', 'length': 1535},
#  {'group': 0, 'id': 'cosmology', 'length': 3689},
#  {'group': 0, 'id': 'cosmos', 'length': 647},
#  {'group': 0, 'id': 'dark energy', 'length': 4196},
#  {'group': 0, 'id': 'dark matter', 'length': 6202},
#  {'group': 0, 'id': 'density functional theory', 'length': 2781},
#  {'group': 0, 'id': 'diffraction', 'length': 2715},
#  {'group': 0, 'id': 'econophysics', 'length': 2050},
#  {'group': 0, 'id': 'effective field theory', 'length': 864},
#  {'group': 0, 'id': 'electrical conduction', 'length': 3105},
#  {'group': 0, 'id': 'electromagnetic', 'length': 2979},
#  {'group': 0, 'id': 'electromagnetic radiation', 'length': 5511},
#  {'group': 0, 'id': 'electroweak theory', 'length': 910},
#  {'group': 0, 'id': 'elementary particle', 'length': 2273},
#  {'group': 0, 'id': 'engineering physics', 'length': 1244},
#  {'group': 0, 'id': 'fermi gas', 'length': 484},
#  {'group': 0, 'id': 'fermi liquid', 'length': 1339},
#  {'group': 0, 'id': 'fluid dynamics', 'length': 2829},
#  {'group': 0, 'id': 'fundamental force', 'length': 2552},
#  {'group': 0, 'id': 'galaxy', 'length': 5431},
#  {'group': 0, 'id': 'gas', 'length': 3170},
#  {'group': 0, 'id': 'gauge theory', 'length': 3267},
#  {'group': 0, 'id': 'general relativity', 'length': 11106},
#  {'group': 0, 'id': 'geophysics', 'length': 2540},
#  {'group': 0, 'id': 'grand unification theory', 'length': 2039},
#  {'group': 0, 'id': 'gravitation physics', 'length': 3389},
#  {'group': 0, 'id': 'gravitational', 'length': 3389},
#  {'group': 0, 'id': 'gravitational radiation', 'length': 5780},
#  {'group': 0, 'id': 'gravitational singularity', 'length': 1517},
#  {'group': 0, 'id': 'gravity', 'length': 3389},
#  {'group': 0, 'id': 'high pressure physics', 'length': 264},
#  {'group': 0, 'id': 'high-energy astrophysics', 'length': 177},
#  {'group': 0, 'id': 'lambda-cdm model', 'length': 109},
#  {'group': 0, 'id': 'laser', 'length': 6475},
#  {'group': 0, 'id': 'laser physics', 'length': 525},
#  {'group': 0, 'id': 'lattice field theory', 'length': 163},
#  {'group': 0, 'id': 'lattice gauge theory', 'length': 783},
#  {'group': 0, 'id': 'liquid', 'length': 2017},
#  {'group': 0, 'id': 'low-temperature physics', 'length': 1404},
#  {'group': 0, 'id': 'm-theory', 'length': 4086},
#  {'group': 0, 'id': 'magnetism', 'length': 2914},
#  {'group': 0, 'id': 'magnetohydrodynamics', 'length': 2833},
#  {'group': 0, 'id': 'many-body theory', 'length': 91},
#  {'group': 0, 'id': 'materials physics', 'length': 3948},
#  {'group': 0, 'id': 'medical physics', 'length': 1385},
#  {'group': 0, 'id': 'molecular physics', 'length': 233},
#  {'group': 0, 'id': 'molecule', 'length': 1862},
#  {'group': 0, 'id': 'nanoscale and mesoscopic physics', 'length': 4831},
#  {'group': 0, 'id': 'nanotechnology', 'length': 4831},
#  {'group': 0, 'id': 'neutrino oscillation', 'length': 2645},
#  {'group': 0, 'id': "newton's law of universal gravitation", 'length': 3182},
#  {'group': 0, 'id': 'nuclear', 'length': 2436},
#  {'group': 0, 'id': 'nuclear astrophysics', 'length': 950},
#  {'group': 0, 'id': 'nuclear physics', 'length': 2436},
#  {'group': 0, 'id': 'optics', 'length': 6651},
#  {'group': 0, 'id': 'optoelectronics', 'length': 586},
#  {'group': 0, 'id': 'particle astrophysics', 'length': 888},
#  {'group': 0, 'id': 'particle physics', 'length': 2605},
#  {'group': 0, 'id': 'particle physics phenomenology', 'length': 326},
#  {'group': 0, 'id': 'phases', 'length': 1017},
#  {'group': 0, 'id': 'phonon', 'length': 2360},
#  {'group': 0, 'id': 'photon', 'length': 5999},
#  {'group': 0, 'id': 'photonics', 'length': 1482},
#  {'group': 0, 'id': 'photovoltaics', 'length': 5880},
#  {'group': 0, 'id': 'physical chemistry', 'length': 1085},
#  {'group': 0, 'id': 'physics of computation', 'length': 70},
#  {'group': 0, 'id': 'planet', 'length': 6470},
#  {'group': 0, 'id': 'planetary astrophysics', 'length': 1889},
#  {'group': 0, 'id': 'plasma physics', 'length': 4151},
#  {'group': 0, 'id': 'polarization (waves)', 'length': 4845},
#  {'group': 0, 'id': 'polymer physics', 'length': 1445},
#  {'group': 0, 'id': 'quantum chemistry', 'length': 1540},
#  {'group': 0, 'id': 'quantum chromodynamics', 'length': 3038},
#  {'group': 0, 'id': 'quantum electrodynamics', 'length': 3122},
#  {'group': 0, 'id': 'quantum electronics', 'length': 1230},
#  {'group': 0, 'id': 'quantum field theory', 'length': 6580},
#  {'group': 0, 'id': 'quantum gravity', 'length': 3888},
#  {'group': 0, 'id': 'quantum information science', 'length': 799},
#  {'group': 0, 'id': 'quantum optics', 'length': 1230},
#  {'group': 0, 'id': 'seesaw mechanism', 'length': 479},
#  {'group': 0, 'id': 'self-organization', 'length': 2688},
#  {'group': 0, 'id': 'semiconductor', 'length': 2547},
#  {'group': 0, 'id': 'solar physics', 'length': 934},
#  {'group': 0, 'id': 'solar system', 'length': 6442},
#  {'group': 0, 'id': 'solid', 'length': 2901},
#  {'group': 0, 'id': 'solid state physics', 'length': 769},
#  {'group': 0, 'id': 'solid-state devices', 'length': 769},
#  {'group': 0, 'id': 'space physics', 'length': 429},
#  {'group': 0, 'id': 'spectral line', 'length': 1345},
#  {'group': 0, 'id': 'spin', 'length': 3197},
#  {'group': 0, 'id': 'spontaneous symmetry breaking', 'length': 2012},
#  {'group': 0, 'id': 'standard model', 'length': 3544},
#  {'group': 0, 'id': 'star', 'length': 7516},
#  {'group': 0, 'id': 'statistical mechanics', 'length': 2512},
#  {'group': 0, 'id': 'stellar astrophysics', 'length': 5177},
#  {'group': 0, 'id': 'string', 'length': 443},
#  {'group': 0, 'id': 'strong', 'length': 1239},
#  {'group': 0, 'id': 'superconductor', 'length': 3268},
#  {'group': 0, 'id': 'superfluid', 'length': 1040},
#  {'group': 0, 'id': 'supernova', 'length': 7711},
#  {'group': 0, 'id': 'superstring theory', 'length': 1804},
#  {'group': 0, 'id': 'supersymmetry', 'length': 3450},
#  {'group': 0, 'id': 'surface physics', 'length': 1090},
#  {'group': 0, 'id': 'theory of everything', 'length': 3788},
#  {'group': 0, 'id': 'universe', 'length': 7179},
#  {'group': 0, 'id': 'vacuum energy', 'length': 1125},
#  {'group': 0, 'id': 'vehicle dynamics', 'length': 607},
#  {'group': 0, 'id': 'weak', 'length': 1889}]

# %% [markdown]
# ## Compiling the links data <a class="anchor" id="Compiling the links data"></a>
#
# We have the nodes, we need to find a way to connect them. We are going to compute the [cosine similarity](https://en.wikipedia.org/wiki/Cosine_similarity) between each of the wikipedia pages. It is called the cosine similarity because a dot product between 2 vectors $\mathbf{A}$ and $\mathbf{B}$ can be express as:
# \begin{equation}
# A\cdot B = \Vert A\Vert_2\Vert B\Vert_2\cos\theta
# \end{equation}
# where $\theta$ is the angle between the 2 vectors. Similarly:
# \begin{equation}
# \cos\theta = \frac{ A\cdot B}{\Vert A\Vert_2\Vert B\Vert_2}
# \end{equation}
# $\cos\theta\in[-1,1]$ and specifically $\cos\theta = 1$ if the 2 vectors are in the same direction or $\cos\theta = -1$ if the 2 vectors are in the opposite direction. The matter here becomes to be able to express a Wikipedia page as a vector. I suggest here a simple approach but there are many ways to achieve this.
#
# We defined earlier the corpus of physics words `physics_corpus`. Each word can be thought as a orthogonal basis defining a vector space where our Wikipedia pages are living in. Each component can be represented by the number of time a specific word appear in a page. As an example, imaging a page $P$ represented by the following list of words:
# ```
# P_list = ["data", "data", "science", "python", "python"]
# ```
# And let's imaging that we have a simple word corpus:
# ```
# corpus = {"engineering", "data", "science", "python"}
# ```
# Then in that basis $P$ could be represented by a vector
# \begin{equation}
# \mathbf{P}=\left(\begin{matrix}
#   0  \\
#   2  \\
#   1  \\
#   2
#  \end{matrix}\right)
# \end{equation}
#
# We need to express each Wikipedia page as such vector.
#
# >Let's start by creating a dataframe with as columns, all the indices of the `nodes_df` dataframe (`nodes_df.index.values`) and as index, the whole `physics_corpus` set.

# %%
# TODO: create a data frame with the index of nodes_df as columns and physics_corpus as index
words_vector =  pd.DataFrame(index=physics_corpus, columns = nodes_df.index.values)
words_vector
# Out:
#                 Wilhelm Conrad Röntgen Hendrik Lorentz Pieter Zeeman  \
# wish                               NaN             NaN           NaN
# günter                             NaN             NaN           NaN
# irreversibility                    NaN             NaN           NaN
# daughter                           NaN             NaN           NaN
# bertotti                           NaN             NaN           NaN
# lifetime                           NaN             NaN           NaN
# highlevel                          NaN             NaN           NaN
# chinas                             NaN             NaN           NaN
# cline                              NaN             NaN           NaN
# qualifying                         NaN             NaN           NaN
# photographyedit                    NaN             NaN           NaN
# lori                               NaN             NaN           NaN
# surveyed                           NaN             NaN           NaN
# mel                                NaN             NaN           NaN
# atmospheric                        NaN             NaN           NaN
# attending                          NaN             NaN           NaN
# deutsch                            NaN             NaN           NaN
# es                                 NaN             NaN           NaN
# sapiens                            NaN             NaN           NaN
# imaging                            NaN             NaN           NaN
# biographical                       NaN             NaN           NaN
# marvels                            NaN             NaN           NaN
# bound                              NaN             NaN           NaN
# signs                              NaN             NaN           NaN
# metastable                         NaN             NaN           NaN
# cells                              NaN             NaN           NaN
# rivista                            NaN             NaN           NaN
# fitzgerald                         NaN             NaN           NaN
# suggest                            NaN             NaN           NaN
# valiant                            NaN             NaN           NaN
# ...                                ...             ...           ...
# peer                             NaN      NaN           NaN              NaN
# substance                        NaN      NaN           NaN              NaN
# simulator                        NaN      NaN           NaN              NaN
# religion                         NaN      NaN           NaN              NaN
# ch                               NaN      NaN           NaN              NaN
# transport                        NaN      NaN           NaN              NaN
# planning                         NaN      NaN           NaN              NaN
# microscopically                  NaN      NaN           NaN              NaN
# authorities                      NaN      NaN           NaN              NaN
# axiom                            NaN      NaN           NaN              NaN
# konstantin                       NaN      NaN           NaN              NaN
# ranging                          NaN      NaN           NaN              NaN
# crawford                         NaN      NaN           NaN              NaN
# macleod                          NaN      NaN           NaN              NaN
# deuteron                         NaN      NaN           NaN              NaN
# ads                              NaN      NaN           NaN              NaN
# lehn                             NaN      NaN           NaN              NaN
# arguing                          NaN      NaN           NaN              NaN
# variational                      NaN      NaN           NaN              NaN
# deng                             NaN      NaN           NaN              NaN
# intergalactic                    NaN      NaN           NaN              NaN
# frame                            NaN      NaN           NaN              NaN
# backus                           NaN      NaN           NaN              NaN
#
#                 weak
# wish             NaN
# günter           NaN
# irreversibility  NaN
# daughter         NaN
# bertotti         NaN
# lifetime         NaN
# highlevel        NaN
# chinas           NaN
# cline            NaN
# qualifying       NaN
# photographyedit  NaN
# lori             NaN
# surveyed         NaN
# mel              NaN
# atmospheric      NaN
# attending        NaN
# deutsch          NaN
# es               NaN
# sapiens          NaN
# imaging          NaN
# biographical     NaN
# marvels          NaN
# bound            NaN
# signs            NaN
# metastable       NaN
# cells            NaN
# rivista          NaN
# fitzgerald       NaN
# suggest          NaN
# valiant          NaN
# ...              ...
# stone            NaN
# qualities        NaN
# doubting         NaN
# ali              NaN
# paula            NaN
# disaster         NaN
# kiel             NaN
# peer             NaN
# substance        NaN
# simulator        NaN
# religion         NaN
# ch               NaN
# transport        NaN
# planning         NaN
# microscopically  NaN
# authorities      NaN
# axiom            NaN
# konstantin       NaN
# ranging          NaN
# crawford         NaN
# macleod          NaN
# deuteron         NaN
# ads              NaN
# lehn             NaN
# arguing          NaN
# variational      NaN
# deng             NaN
# intergalactic    NaN
# frame            NaN
# backus           NaN
#
# [12725 rows x 339 columns]

# %% [markdown]
# To fill this table we are going to use the [`value_counts`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) function on the list of words contained in `nobel_df["physics_list_clean"]` and `physics_df["physics_list_clean"]`.
#
# >Write a function that takes a list and return a value_counts. The return value should be a pandas series with the words as index. We are using this function to populate the `words_vector` dataframe. Note that because `words_vector` already has an index, the values get populated at the right place automatically.

# %%
#TODO: write a function that take a list and return the a word count
def count_words(list_to_count):
    return pd.Series(list_to_count).value_counts()

words_vector.loc[:,nobel_df.index] = nobel_df["physics_list_clean"].apply(count_words).transpose()
words_vector.loc[:,physics_df.index] = physics_df["physics_list_clean"].apply(count_words).transpose()
words_vector
# Out:
#                 Wilhelm Conrad Röntgen Hendrik Lorentz Pieter Zeeman  \
# wish                               NaN             NaN           NaN
# günter                             NaN             NaN           NaN
# irreversibility                    NaN             NaN           NaN
# daughter                           NaN               1           NaN
# bertotti                           NaN             NaN           NaN
# lifetime                           NaN             NaN           NaN
# highlevel                          NaN             NaN           NaN
# wish                            NaN                      NaN ...         NaN
# günter                          NaN                      NaN ...         NaN
# irreversibility                 NaN                      NaN ...         NaN
# daughter                          2                        4 ...         NaN
# bertotti                        NaN                      NaN ...         NaN
# lifetime                        NaN                      NaN ...         NaN
# highlevel                       NaN                      NaN ...         NaN
# chinas                          NaN                      NaN ...         NaN
# cline                           NaN                      NaN ...         NaN
# qualifying                      NaN                      NaN ...         NaN
# photographyedit                 NaN                      NaN ...         NaN
# lori                            NaN                      NaN ...         NaN
# surveyed                        NaN                      NaN ...         NaN
# mel                             NaN                      NaN ...         NaN
# atmospheric                     NaN                        1 ...         NaN
# attending                       NaN                      NaN ...         NaN
# deutsch                         NaN                      NaN ...         NaN
# es                              NaN                      NaN ...         NaN
# sapiens                         NaN                      NaN ...         NaN
# imaging                         NaN                      NaN ...           1
# biographical                      2                        1 ...         NaN
# marvels                         NaN                      NaN ...         NaN
# bound                           NaN                      NaN ...         NaN
# signs                           NaN                      NaN ...         NaN
# metastable                      NaN                      NaN ...         NaN
# cells                           NaN                      NaN ...         NaN
# rivista                         NaN                      NaN ...         NaN
# fitzgerald                      NaN                      NaN ...         NaN
# suggest                           1                        1 ...         NaN
# valiant                         NaN                      NaN ...         NaN
# ...                             ...                      ... ...         ...
# stone                           NaN                      NaN ...         NaN
# qualities                       NaN                      NaN ...         NaN
# doubting                        NaN                      NaN ...         NaN
# ali                             NaN                      NaN ...         NaN
# paula                           NaN                      NaN ...         NaN
# disaster                        NaN                      NaN ...         NaN
# kiel                            NaN                      NaN ...         NaN
# peer                            NaN                        1 ...         NaN
# substance                       NaN                      NaN ...         NaN
# simulator                       NaN                      NaN ...           1
# religion                          1                      NaN ...         NaN
# ch                              NaN                      NaN ...         NaN
# transport                       NaN                      NaN ...           3
# planning                        NaN                        3 ...         NaN
# microscopically                 NaN                      NaN ...         NaN
# authorities                     NaN                      NaN ...         NaN
# axiom                           NaN                      NaN ...         NaN
# konstantin                      NaN                      NaN ...         NaN
# ranging                         NaN                      NaN ...         NaN
# crawford                        NaN                      NaN ...         NaN
# macleod                         NaN                      NaN ...         NaN
# deuteron                        NaN                      NaN ...         NaN
# ads                             NaN                      NaN ...         NaN
# lehn                            NaN                      NaN ...         NaN
# arguing                         NaN                      NaN ...         NaN
# variational                     NaN                      NaN ...         NaN
# deng                            NaN                      NaN ...         NaN
# intergalactic                   NaN                      NaN ...         NaN
# frame                           NaN                      NaN ...         NaN
# backus                          NaN                      NaN ...         NaN
#
#                 supernova superstring theory supersymmetry surface physics  \
# wish                  NaN                NaN           NaN             NaN
# günter                NaN                NaN           NaN             NaN
# irreversibility       NaN                NaN           NaN             NaN
# daughter                1                NaN           NaN             NaN
# bertotti              NaN                NaN           NaN             NaN
# lifetime                1                NaN           NaN             NaN
# highlevel             NaN                NaN           NaN             NaN
# chinas                NaN                NaN           NaN             NaN
# cline                 NaN                NaN           NaN             NaN
# qualifying            NaN                NaN           NaN             NaN
# photographyedit       NaN                NaN           NaN             NaN
# lori                  NaN                NaN           NaN             NaN
# signs                            NaN      NaN           NaN              NaN
# metastable                       NaN      NaN           NaN              NaN
# cells                            NaN      NaN           NaN              NaN
# rivista                          NaN      NaN           NaN              NaN
# fitzgerald                       NaN      NaN           NaN              NaN
# suggest                            1        3           NaN              NaN
# valiant                          NaN      NaN           NaN              NaN
# ...                              ...      ...           ...              ...
# stone                            NaN      NaN           NaN              NaN
# qualities                          1        7           NaN              NaN
# doubting                         NaN        1           NaN              NaN
# ali                              NaN        1           NaN              NaN
# paula                            NaN      NaN           NaN              NaN
# disaster                         NaN      NaN           NaN              NaN
# kiel                             NaN      NaN           NaN              NaN
# peer                               1      NaN           NaN              NaN
# substance                        NaN        3           NaN              NaN
# simulator                        NaN      NaN           NaN              NaN
# religion                         NaN        1           NaN              NaN
# ch                                 4        1           NaN              NaN
# transport                        NaN      NaN           NaN              NaN
# planning                         NaN      NaN           NaN              NaN
# microscopically                  NaN      NaN           NaN              NaN
# authorities                      NaN      NaN           NaN              NaN
# axiom                            NaN      NaN           NaN              NaN
# konstantin                       NaN      NaN           NaN              NaN
# ranging                          NaN        1           NaN              NaN
# crawford                         NaN      NaN           NaN              NaN
# macleod                          NaN      NaN           NaN              NaN
# deuteron                         NaN      NaN           NaN              NaN
# ads                              NaN      NaN           NaN              NaN
# lehn                             NaN      NaN           NaN              NaN
# arguing                            1      NaN           NaN              NaN
# variational                      NaN      NaN           NaN              NaN
# deng                             NaN      NaN           NaN              NaN
# intergalactic                    NaN        2           NaN              NaN
# frame                            NaN      NaN           NaN              NaN
# backus                           NaN      NaN           NaN              NaN
#
#                 weak
# wish             NaN
# günter           NaN
# irreversibility  NaN
# daughter         NaN
# bertotti         NaN
# lifetime           2
# highlevel        NaN
# chinas           NaN
# cline            NaN
# qualifying       NaN
# photographyedit  NaN
# lori             NaN
# surveyed         NaN
# mel              NaN
# atmospheric      NaN
# attending        NaN
# deutsch          NaN
# es               NaN
# sapiens          NaN
# imaging          NaN
# biographical     NaN
# marvels          NaN
# bound              1
# signs            NaN
# metastable       NaN
# cells            NaN
# rivista          NaN
# fitzgerald       NaN
# suggest          NaN
# valiant          NaN
# ...              ...
# stone            NaN
# qualities        NaN
# doubting         NaN
# ali              NaN
# paula            NaN
# disaster         NaN
# kiel             NaN
# peer             NaN
# substance        NaN
# simulator        NaN
# religion         NaN
# ch               NaN
# transport        NaN
# planning         NaN
# microscopically  NaN
# authorities      NaN
# axiom            NaN
# konstantin       NaN
# ranging          NaN
# crawford         NaN
# macleod          NaN
# deuteron         NaN
# ads              NaN
# lehn             NaN
# arguing          NaN
# variational      NaN
# deng             NaN
# intergalactic    NaN
# frame            NaN
# backus           NaN
#
# [12725 rows x 339 columns]

# %% [markdown]
# There are many entries in this dataframe that appear as `NaN`. We just need to replace those missing values by 0 since they indicate that no records of the word were found for those pages.
#
# >Use the function [`pd.fillna`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.fillna.html
# lori                                         0.0                  0.0
# surveyed                                     0.0                  0.0
# mel                                          0.0                  0.0
# atmospheric                                  0.0                  0.0
# attending                                    0.0                  0.0
# deutsch                                      0.0                  0.0
# es                                           0.0                  0.0
# sapiens                                      0.0                  0.0
# imaging                                      0.0                  0.0
# biographical                                 0.0                  2.0
# marvels                                      0.0                  0.0
# bound                                        1.0                  0.0
# signs                                        0.0                  0.0
# metastable                                   0.0                  0.0
# cells                                        0.0                  0.0
# rivista                                      0.0                  0.0
# fitzgerald                                   0.0                  0.0
# suggest                                      0.0                  1.0
# valiant                                      0.0                  0.0
# ...                                          ...                  ...
# stone                                        0.0                  0.0
# qualities                                    0.0                  0.0
# doubting                                     0.0                  0.0
# ali                                          0.0                  0.0
# paula                                        0.0                  0.0
# disaster                                     0.0                  0.0
# kiel                                         2.0                  0.0
# peer                                         0.0                  0.0
# substance                                    0.0                  0.0
# simulator                                    0.0                  0.0
# religion                                     0.0                  1.0
# ch                                           0.0                  0.0
# transport                                    0.0                  0.0
# planning                                     0.0                  0.0
# microscopically                              0.0                  0.0
# authorities                                  0.0                  0.0
# axiom                                        0.0                  0.0
# konstantin                                   0.0                  0.0
# ranging                                      0.0                  0.0
# crawford                                     0.0                  0.0
# macleod                                      0.0                  0.0
# deuteron                                     0.0                  0.0
# ads                                          0.0                  0.0
# lehn                                         0.0                  0.0
# arguing                                      0.0                  0.0
# variational                                  0.0                  0.0
# deng                                         0.0                  0.0
# intergalactic                                0.0                  0.0
# frame                                        0.0                  0.0
# backus                                       0.0                  0.0
#
#                  Albert Abraham Michelson  ...   superfluid  supernova  \
# wish                                  0.0  ...          0.0        0.0
# günter                                0.0  ...          0.0        0.0
# irreversibility                       0.0  ...          0.0        0.0
# daughter                              4.0  ...          0.0        1.0
# bertotti                              0.0  ...          0.0        0.0
# lifetime                              0.0  ...          0.0        1.0
# highlevel                             0.0  ...          0.0        0.0
# chinas                                0.0  ...          0.0        0.0
# cline                                 0.0  ...          0.0        0.0
# qualifying                            0.0  ...          0.0        0.0
# photographyedit                       0.0  ...          0.0        0.0
# lori                                  0.0  ...          0.0        0.0
# surveyed                              0.0  ...          0.0        0.0
# mel                                   0.0  ...          0.0        0.0
# atmospheric                           1.0  ...          0.0        0.0
# attending                             0.0  ...          0.0        0.0
# deutsch                               0.0  ...          0.0        0.0
# es                                    0.0  ...          0.0        0.0
# sapiens                               0.0  ...          0.0        0.0
# imaging                               0.0  ...          1.0        4.0
# biographical                          1.0  ...          0.0        0.0
# marvels                               0.0  ...          0.0        0.0
# bound                                 0.0  ...          0.0        0.0
# signs                                 0.0  ...          0.0        0.0
# metastable                            0.0  ...          0.0        0.0
# cells                                 0.0  ...          0.0        0.0
# rivista                               0.0  ...          0.0        0.0
# fitzgerald                            0.0  ...          0.0        0.0
# suggest                               1.0  ...          0.0        2.0
# valiant                               0.0  ...          0.0        0.0
# ...                                   ...  ...          ...        ...
# stone                                 0.0  ...          0.0        0.0
# qualities                             0.0  ...          0.0        0.0
# doubting                              0.0  ...          0.0        0.0
# ali                                   0.0  ...          0.0        0.0
# paula                                 0.0  ...          0.0        0.0
# disaster                              0.0  ...          0.0        0.0
# kiel                                  0.0  ...          0.0        0.0
# peer                                  1.0  ...          0.0        0.0
# substance                             0.0  ...          0.0        0.0
# simulator                             0.0  ...          1.0        0.0
# religion                              0.0  ...          0.0        0.0
# ch                                    0.0  ...          0.0        1.0
# transport                             0.0  ...          3.0        0.0
# planning                              3.0  ...          0.0        0.0
# microscopically                       0.0  ...          0.0        0.0
# authorities                           0.0  ...          0.0        0.0
# axiom                                 0.0  ...          0.0        0.0
# konstantin                            0.0  ...          0.0        0.0
# ranging                               0.0  ...          0.0        0.0
# crawford                              0.0  ...          0.0        0.0
# macleod                               0.0  ...          0.0        0.0
# deuteron                              0.0  ...          0.0        0.0
# ads                                   0.0  ...          0.0        0.0
# lehn                                  0.0  ...          0.0        0.0
# arguing                               0.0  ...          0.0        0.0
# variational                           0.0  ...          0.0        0.0
# deng                                  0.0  ...          0.0        0.0
# intergalactic                         0.0  ...          0.0        2.0
# frame                                 0.0  ...          0.0        0.0
# backus                                0.0  ...          0.0        0.0
#
#                  superstring theory  supersymmetry  surface physics  \
# wish                            0.0            0.0              0.0
# günter                          0.0            0.0              0.0
# irreversibility                 0.0            0.0              0.0
# daughter                        0.0            0.0              0.0
# bertotti                        0.0            0.0              0.0
# lifetime                        0.0            0.0              0.0
# highlevel                       0.0            0.0              0.0
# chinas                          0.0            0.0              0.0
# cline                           0.0            0.0              0.0
# qualifying                      0.0            0.0              0.0
# photographyedit                 0.0            0.0              0.0
# lori                            0.0            0.0              0.0
# surveyed                        0.0            0.0              0.0
# mel                             0.0            0.0              0.0
# atmospheric                     0.0            0.0              0.0
# attending                       0.0            0.0              0.0
# deutsch                         0.0            0.0              0.0
# es                              0.0            0.0              0.0
# sapiens                         0.0            0.0              0.0
# imaging                         0.0            0.0              0.0
# biographical                    0.0            0.0              0.0
# marvels                         0.0            0.0              0.0
# bound                           1.0            1.0              0.0
# signs                           0.0            1.0              0.0
# metastable                      0.0            0.0              0.0
# cells                           0.0            0.0              1.0
# rivista                         0.0            0.0              0.0
# fitzgerald                      0.0            0.0              0.0
# suggest                         0.0            0.0              0.0
# valiant                         0.0            0.0              0.0
# ...                             ...            ...              ...
# stone                           0.0            0.0              0.0
# qualities                       0.0            0.0              0.0
# doubting                        0.0            0.0              0.0
# ali                             0.0            0.0              0.0
# paula                           0.0            0.0              0.0
# disaster                        0.0            0.0              0.0
# kiel                            0.0            0.0              0.0
# peer                            0.0            0.0              0.0
# substance                       0.0            0.0              0.0
# simulator                       0.0            0.0              0.0
# religion                        0.0            0.0              0.0
# ch                              0.0            0.0              0.0
# transport                       0.0            0.0              0.0
# planning                        0.0            0.0              0.0
# microscopically                 0.0            0.0              0.0
# authorities                     0.0            0.0              0.0
# axiom                           0.0            0.0              0.0
# konstantin                      0.0            1.0              0.0
# ranging                         0.0            1.0              0.0
# crawford                        0.0            0.0              0.0
# macleod                         0.0            0.0              0.0
# sapiens                       0.0   0.0
# imaging                       0.0   0.0
# biographical                  0.0   0.0
# marvels                       0.0   0.0
# bound                         0.0   1.0
# signs                         0.0   0.0
# metastable                    0.0   0.0
# cells                         0.0   0.0
# rivista                       0.0   0.0
# fitzgerald                    0.0   0.0
# suggest                       0.0   0.0
# valiant                       0.0   0.0
# ...                           ...   ...
# stone                         0.0   0.0
# qualities                     0.0   0.0
# doubting                      0.0   0.0
# ali                           0.0   0.0
# paula                         0.0   0.0
# disaster                      0.0   0.0
# kiel                          0.0   0.0
# peer                          0.0   0.0
# substance                     0.0   0.0
# simulator                     0.0   0.0
# religion                      0.0   0.0
# ch                            0.0   0.0
# transport                     0.0   0.0
# planning                      0.0   0.0
# microscopically               0.0   0.0
# authorities                   0.0   0.0
# axiom                         0.0   0.0
# konstantin                    0.0   0.0
# ranging                       0.0   0.0
# crawford                      0.0   0.0
# macleod                       0.0   0.0
# deuteron                      0.0   0.0
# ads                           0.0   0.0
# lehn                          0.0   0.0
# arguing                       0.0   0.0
# variational                   0.0   0.0
# deng                          0.0   0.0
# intergalactic                 0.0   0.0
# frame                         0.0   0.0
# backus                        0.0   0.0
#
# [12725 rows x 339 columns]

# %% [markdown]
# >- Write a function that takes 2 vectors (2 pandas series) and return the cosine similarity index. You can use the function [`dot`](http://pandas.pydata.org/pandas-docs/version/0.18.1/generated/pandas.Series.dot.html), [`pow`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.pow.html) and `sum` if you like.
# - Use this function to fill the `similarity_df` dataframe
# - Bonus points if you can compute this dataframe using matrix algebra ([`dot`](http://pandas.pydata.org/pandas-docs/version/0.18.1/generated/pandas.DataFrame.dot.html)) without having to iterate through the columns. Hint create 2 dataframe: one that is the dot products of words_vector with itself and one that represent a matrix of norm products. Then divide one matrix by the other element wise. For this case, you would not need to use the `compute_similarity` function.

# %%
# TODO: write a function that takes 2 vectors and return the cosine similarity index
def compute_similarity(vect1, vect2):
    return vect1.dot(vect2) / (np.sqrt(vect1.pow(2).sum()) * np.sqrt(vect2.pow(2).sum()))

similarity_df = pd.DataFrame(columns=words_vector.columns, index=words_vector.columns, dtype=float)

# TODO: fill the similarity_df dataframe with the cosine similarity
for i in range(336):
    for j in range(336):
        similarity_df.iloc[i,j] = compute_similarity(words_vector.T.iloc[i,:], words_vector.iloc[:,j])

# TODO: bonus points if you can compute this dataframe using matrix algebra 


similarity_df
# Out:
#                                  Wilhelm Conrad Röntgen  Hendrik Lorentz  \
# Wilhelm Conrad Röntgen                         1.000000         0.185980
# Hendrik Lorentz                                0.185980         1.000000
# Pieter Zeeman                                  0.235582         0.372728
# Antoine Henri Becquerel                        0.246754         0.220099
# Pierre Curie                                   0.243904         0.179496
# Maria Skłodowska-Curie                         0.264306         0.181588
# Lord Rayleigh                                  0.279527         0.205124
# Philipp Eduard Anton von Lenard                0.322531         0.255789
# Joseph John Thomson                            0.271153         0.181050
# Albert Abraham Michelson                       0.226106         0.272384
# Gabriel Lippmann                               0.195201         0.250017
# Guglielmo Marconi                              0.187961         0.167760
# Karl Ferdinand Braun                           0.238879         0.186334
# Johannes Diderik van der Waals                 0.188112         0.245185
# Wilhelm Wien                                   0.348077         0.220580
# Nils Gustaf Dalén                              0.272349         0.220173
# Heike Kamerlingh-Onnes                         0.195516         0.216595
# Max von Laue                                   0.206985         0.182463
# William Henry Bragg                            0.290272         0.227259
# William Lawrence Bragg                         0.268874         0.217115
# Charles Glover Barkla                          0.341671         0.239879
# Max Planck                                     0.196423         0.226765
# Johannes Stark                                 0.275262         0.238544
# Charles Édouard Guillaume                      0.186343         0.179180
# Albert Einstein                                0.191417         0.382107
# Niels Bohr                                     0.187483         0.207431
# Robert Andrews Millikan                        0.213136         0.212933
# Manne Siegbahn                                 0.307693         0.244213
# James Franck                                   0.285756         0.224116
# Gustav Hertz                                   0.229287         0.171727
# ...                                                 ...              ...
# quantum optics                                 0.063332         0.143168
# seesaw mechanism                               0.046316         0.086250
# self-organization                              0.141374         0.199345
# semiconductor                                  0.110332         0.127522
# solar physics                                  0.103033         0.124202
# solar system                                   0.064973         0.092300
# solid                                          0.097357         0.100780
# solid state physics                            0.123079         0.158766
# solid-state devices                            0.123079         0.158766
# space physics                                  0.133045         0.153593
# spectral line                                  0.061985         0.073284
# spin                                           0.061045         0.126422
# spontaneous symmetry breaking                  0.052806         0.123694
# standard model                                 0.083372         0.168396
# star                                           0.067271         0.084494
# statistical mechanics                          0.060354         0.139450
# stellar astrophysics                           0.128996         0.141998
# string                                         0.048446         0.147640
# strong                                         0.070118         0.104974
# superconductor                                 0.095733         0.149620
# superfluid                                     0.069598         0.121991
# supernova                                      0.063835         0.073885
# superstring theory                             0.067767         0.215487
# supersymmetry                                  0.082096         0.205946
# surface physics                                0.075353         0.073176
# theory of everything                           0.098687         0.290997
# universe                                       0.100884         0.165452
# vacuum energy                                       NaN              NaN
# vehicle dynamics                                    NaN              NaN
# weak                                                NaN              NaN
#
#                                  Pieter Zeeman  Antoine Henri Becquerel  \
# Wilhelm Conrad Röntgen                0.235582                 0.246754
# Hendrik Lorentz                       0.372728                 0.220099
# Pieter Zeeman                         1.000000                 0.257315
# Antoine Henri Becquerel               0.257315                 1.000000
# Pierre Curie                          0.209804                 0.310111
# Maria Skłodowska-Curie                0.210226                 0.277176
# Lord Rayleigh                         0.217910                 0.199766
# Philipp Eduard Anton von Lenard       0.282626                 0.243003
# Joseph John Thomson                   0.209114                 0.213223
# Albert Abraham Michelson              0.268707                 0.209687
# Gabriel Lippmann                      0.280897                 0.388334
# Guglielmo Marconi                     0.148402                 0.149956
# Karl Ferdinand Braun                  0.225723                 0.187691
# Johannes Diderik van der Waals        0.323583                 0.154021
# Wilhelm Wien                          0.251367                 0.231110
# Nils Gustaf Dalén                     0.329688                 0.294886
# Heike Kamerlingh-Onnes                0.383467                 0.180280
# Max von Laue                          0.186934                 0.143594
# William Henry Bragg                   0.279248                 0.198526
# William Lawrence Bragg                0.316629                 0.236045
# Charles Glover Barkla                 0.344303                 0.266171
# Max Planck                            0.181782                 0.157539
# Johannes Stark                        0.286928                 0.187100
# solid                                0.104058                0.080880
# solid state physics                  0.111999                0.130644
# solid-state devices                  0.111999                0.130644
# space physics                        0.132310                0.145529
# spectral line                        0.065878                0.060437
# spin                                 0.060955                0.064531
# spontaneous symmetry breaking        0.069079                0.068041
# standard model                       0.090545                0.095337
# star                                 0.092719                0.109030
# statistical mechanics                0.056635                0.063254
# stellar astrophysics                 0.135331                0.171261
# string                               0.042797                0.048724
# strong                               0.063033                0.063000
# superconductor                       0.129685                0.112019
# superfluid                           0.073215                0.089659
# supernova                            0.061602                0.068067
# superstring theory                   0.058849                0.068095
# supersymmetry                        0.088676                0.100521
# surface physics                      0.106891                0.104622
# theory of everything                 0.098525                0.119297
# universe                             0.105708                0.142642
# vacuum energy                             NaN                     NaN
# vehicle dynamics                          NaN                     NaN
# weak                                      NaN                     NaN
#
#                                  Lord Rayleigh  \
# Wilhelm Conrad Röntgen                0.279527
# Hendrik Lorentz                       0.205124
# Pieter Zeeman                         0.217910
# Antoine Henri Becquerel               0.199766
# Pierre Curie                          0.231557
# Maria Skłodowska-Curie                0.252649
# Lord Rayleigh                         1.000000
# Philipp Eduard Anton von Lenard       0.227093
# Joseph John Thomson                   0.346124
# Albert Abraham Michelson              0.338095
# Gabriel Lippmann                      0.202021
# Guglielmo Marconi                     0.222351
# Karl Ferdinand Braun                  0.189419
# Johannes Diderik van der Waals        0.166981
# Wilhelm Wien                          0.255018
# Nils Gustaf Dalén                     0.229119
# Heike Kamerlingh-Onnes                0.181555
# Max von Laue                          0.193084
# William Henry Bragg                   0.444351
# William Lawrence Bragg                0.384170
# Charles Glover Barkla                 0.384317
# Max Planck                            0.193041
# Johannes Stark                        0.206660
# Charles Édouard Guillaume             0.198911
# Albert Einstein                       0.200979
# Niels Bohr                            0.218515
# Robert Andrews Millikan               0.293758
# Manne Siegbahn                        0.298037
# James Franck                          0.260716
# Gustav Hertz                          0.204817
# ...                                        ...
# quantum optics                        0.078562
# seesaw mechanism                      0.042063
# self-organization                     0.220495
# semiconductor                         0.092974
# solar physics                         0.104793
# solar system                          0.064672
# solid                                 0.068635
# solid state physics                   0.128731
# solid-state devices                   0.128731
# space physics                         0.135054
# spectral line                         0.057426
# spin                                  0.066559
# spontaneous symmetry breaking         0.062378
# standard model                        0.108481
# star                                  0.073875
# statistical mechanics                 0.070949
# stellar astrophysics                  0.125912
# string                                0.094627
# strong                                0.080234
# superconductor                        0.110404
# superfluid                            0.079245
# supernova                             0.058784
# superstring theory                    0.139080
# supersymmetry                         0.121577
# surface physics                       0.078784
# theory of everything                  0.174022
# universe                              0.116242
# vacuum energy                              NaN
# vehicle dynamics                           NaN
# weak                                       NaN
#
#                                  Philipp Eduard Anton von Lenard  \
# Wilhelm Conrad Röntgen                                  0.322531
# Hendrik Lorentz                                         0.255789
# Pieter Zeeman                                           0.282626
# Antoine Henri Becquerel                                 0.243003
# Pierre Curie                                            0.211746
# Maria Skłodowska-Curie                                  0.238631
# Lord Rayleigh                                           0.227093
# Philipp Eduard Anton von Lenard                         1.000000
# Joseph John Thomson                                     0.313150
# Albert Abraham Michelson                                0.254457
# Gabriel Lippmann                                        0.243385
# Guglielmo Marconi                                       0.179897
# Karl Ferdinand Braun                                    0.274044
# Johannes Diderik van der Waals                          0.207502
# Wilhelm Wien                                            0.308723
# Nils Gustaf Dalén                                       0.284624
# Heike Kamerlingh-Onnes                                  0.211928
# Max von Laue                                            0.264253
# William Henry Bragg                                     0.253032
# William Lawrence Bragg                                  0.276827
# Charles Glover Barkla                                   0.311881
# Max Planck                                              0.248336
# Johannes Stark                                          0.404243
# Charles Édouard Guillaume                               0.208841
# Albert Einstein                                         0.344082
# Niels Bohr                                              0.235466
# Robert Andrews Millikan                                 0.252910
# Manne Siegbahn                                          0.350983
# James Franck                                            0.329560
# Gustav Hertz                                            0.286513
# ...                                                          ...
# quantum optics                                          0.139994
# seesaw mechanism                                        0.063882
# self-organization                                       0.194282
# semiconductor                                           0.154545
# solar physics                                           0.166729
# solar system                                            0.081670
# solid                                                   0.129073
# solid state physics                                     0.209982
# solid-state devices                                     0.209982
# space physics                                           0.213357
# spectral line                                           0.096393
# spin                                                    0.096468
# spontaneous symmetry breaking                           0.084680
# standard model                                          0.161595
# star                                                    0.082872
# statistical mechanics                                   0.096353
# stellar astrophysics                                    0.160264
# string                                                  0.092921
# strong                                                  0.114221
# superconductor                                          0.143127
# superfluid                                              0.136562
# supernova                                               0.075325
# superstring theory                                      0.115500
# supersymmetry                                           0.152290
# surface physics                                         0.102614
# theory of everything                                    0.206807
# universe                                                0.158576
# vacuum energy                                                NaN
# vehicle dynamics                                             NaN
# weak                                                         NaN
#
#                                  Joseph John Thomson  \
# Wilhelm Conrad Röntgen                      0.271153
# Hendrik Lorentz                             0.181050
# Pieter Zeeman                               0.209114
# Antoine Henri Becquerel                     0.213223
# Pierre Curie                                0.201587
# Maria Skłodowska-Curie                      0.197374
# Lord Rayleigh                               0.346124
# Philipp Eduard Anton von Lenard             0.313150
# Joseph John Thomson                         1.000000
# Albert Abraham Michelson                    0.262140
# Gabriel Lippmann                            0.165648
# Guglielmo Marconi                           0.179024
# Karl Ferdinand Braun                        0.170546
# Johannes Diderik van der Waals              0.137367
# Wilhelm Wien                                0.255363
# Nils Gustaf Dalén                           0.212254
# Heike Kamerlingh-Onnes                      0.156190
# Max von Laue                                0.128131
# William Henry Bragg                         0.338256
# William Lawrence Bragg                      0.306046
# Charles Glover Barkla                       0.350492
# Max Planck                                  0.193205
# Johannes Stark                              0.176341
# Charles Édouard Guillaume                   0.168131
# Albert Einstein                             0.166047
# Niels Bohr                                  0.226285
# Robert Andrews Millikan                     0.271659
# Manne Siegbahn                              0.249952
# James Franck                                0.229529
# Gustav Hertz                                0.160884
# ...                                              ...
# quantum optics                              0.086930
# seesaw mechanism                            0.097642
# self-organization                           0.145692
# semiconductor                               0.169885
# solar physics                               0.099332
# solar system                                0.086670
# solid                                       0.122546
# solid state physics                         0.153434
# solid-state devices                         0.153434
# space physics                               0.181862
# spectral line                               0.088707
# spin                                        0.120796
# spontaneous symmetry breaking               0.081445
# standard model                              0.174599
# star                                        0.098960
# statistical mechanics                       0.075187
# stellar astrophysics                        0.139478
# string                                      0.072310
# strong                                      0.109756
# superconductor                              0.161858
# superfluid                                  0.089759
# supernova                                   0.081221
# superstring theory                          0.109685
# supersymmetry                               0.133455
# surface physics                             0.105196
# theory of everything                        0.160041
# universe                                    0.139934
# vacuum energy                                    NaN
# vehicle dynamics                                 NaN
# weak                                             NaN
#
#                                  Albert Abraham Michelson  ...   superfluid  \
# Wilhelm Conrad Röntgen                           0.226106  ...     0.069598
# Hendrik Lorentz                                  0.272384  ...     0.121991
# Pieter Zeeman                                    0.268707  ...     0.095153
# Antoine Henri Becquerel                          0.209687  ...     0.072694
# Pierre Curie                                     0.194248  ...     0.073215
# Maria Skłodowska-Curie                           0.226771  ...     0.089659
# Lord Rayleigh                                    0.338095  ...     0.079245
# Philipp Eduard Anton von Lenard                  0.254457  ...     0.136562
# Joseph John Thomson                              0.262140  ...     0.089759
# Albert Abraham Michelson                         1.000000  ...     0.085421
# Gabriel Lippmann                                 0.248214  ...     0.107190
# Guglielmo Marconi                                0.249472  ...     0.095253
# Karl Ferdinand Braun                             0.203362  ...     0.099405
# Johannes Diderik van der Waals                   0.162048  ...     0.108212
# Wilhelm Wien                                     0.219258  ...     0.111046
# Nils Gustaf Dalén                                0.269780  ...     0.111735
# Heike Kamerlingh-Onnes                           0.183836  ...     0.146184
# Max von Laue                                     0.157481  ...     0.102746
# William Henry Bragg                              0.396684  ...     0.079139
# William Lawrence Bragg                           0.322974  ...     0.102822
# Charles Glover Barkla                            0.285210  ...     0.084391
# Max Planck                                       0.191277  ...     0.148911
# Johannes Stark                                   0.213077  ...     0.106322
# Charles Édouard Guillaume                        0.214712  ...     0.075641
# Albert Einstein                                  0.275524  ...     0.162945
# Niels Bohr                                       0.205474  ...     0.158610
# Robert Andrews Millikan                          0.371348  ...     0.119046
# Manne Siegbahn                                   0.293134  ...     0.123667
# James Franck                                     0.282254  ...     0.143852
# Gustav Hertz                                     0.187182  ...     0.100047
# ...                                                   ...  ...          ...
# quantum optics                                   0.099151  ...     0.650038
# seesaw mechanism                                 0.046514  ...     0.071948
# self-organization                                0.145036  ...     0.209518
# semiconductor                                    0.108630  ...     0.211045
# solar physics                                    0.111945  ...     0.199187
# solar system                                     0.078332  ...     0.114790
# solid                                            0.088538  ...     0.202538
# solid state physics                              0.114566  ...     0.283238
# solid-state devices                              0.114566  ...     0.283238
# space physics                                    0.126055  ...     0.229818
# spectral line                                    0.056369  ...     0.119428
# spin                                             0.074337  ...     0.280044
# spontaneous symmetry breaking                    0.057792  ...     0.168468
# standard model                                   0.076227  ...     0.283789
# star                                             0.115728  ...     0.148393
# statistical mechanics                            0.069869  ...     0.219235
# stellar astrophysics                             0.143579  ...     0.159086
# string                                           0.048724  ...     0.162300
# strong                                           0.055838  ...     0.157161
# superconductor                                   0.095474  ...     0.283492
# superfluid                                       0.085421  ...     1.000000
# supernova                                        0.095191  ...     0.125150
# superstring theory                               0.075190  ...     0.183894
# surface physics                   0.082393            0.072302       0.085154
# theory of everything              0.116114            0.674630       0.603363
# universe                          0.175400            0.198123       0.230712
# vacuum energy                          NaN                 NaN            NaN
# vehicle dynamics                       NaN                 NaN            NaN
# weak                                   NaN                 NaN            NaN
#
#                                  surface physics  theory of everything  \
# Wilhelm Conrad Röntgen                  0.075353              0.098687
# Hendrik Lorentz                         0.073176              0.290997
# Pieter Zeeman                           0.074647              0.120857
# Antoine Henri Becquerel                 0.088253              0.099746
# Pierre Curie                            0.106891              0.098525
# Maria Skłodowska-Curie                  0.104622              0.119297
# Lord Rayleigh                           0.078784              0.174022
# Philipp Eduard Anton von Lenard         0.102614              0.206807
# Joseph John Thomson                     0.105196              0.160041
# Albert Abraham Michelson                0.071441              0.121639
# Gabriel Lippmann                        0.096959              0.111153
# Guglielmo Marconi                       0.056471              0.113663
# Karl Ferdinand Braun                    0.057468              0.082419
# Johannes Diderik van der Waals          0.090654              0.149360
# Wilhelm Wien                            0.056549              0.142143
# Nils Gustaf Dalén                       0.075494              0.102666
# Heike Kamerlingh-Onnes                  0.061497              0.088661
# Max von Laue                            0.051482              0.141493
# William Henry Bragg                     0.093217              0.116497
# William Lawrence Bragg                  0.117823              0.137093
# Charles Glover Barkla                   0.115138              0.121442
# Max Planck                              0.069029              0.217724
# Johannes Stark                          0.064059              0.145395
# Charles Édouard Guillaume               0.046655              0.069621
# Albert Einstein                         0.074585              0.341503
# Niels Bohr                              0.069147              0.197293
# Robert Andrews Millikan                 0.098400              0.197312
# Manne Siegbahn                          0.156534              0.134475
# James Franck                            0.109389              0.157152
# Gustav Hertz                            0.061516              0.120128
# ...                                          ...                   ...
# quantum optics                          0.073305              0.307060
# seesaw mechanism                        0.052631              0.203652
# self-organization                       0.166700              0.352411
# semiconductor                           0.155264              0.197527
# solar physics                           0.103136              0.186148
# solar system                            0.075811              0.111886
# solid                                   0.227624              0.154666
# solid state physics                     0.171862              0.317906
# solid-state devices                     0.171862              0.317906
# space physics                           0.121734              0.251422
# spectral line                           0.108903              0.107408
# spin                                    0.074431              0.235759
# spontaneous symmetry breaking           0.060859              0.271307
# standard model                          0.096415              0.552149
# star                                    0.103357              0.105018
# statistical mechanics                   0.092284              0.237367
# stellar astrophysics                    0.129239              0.191434
# string                                  0.057962              0.497779
# strong                                  0.062632              0.302474
# superconductor                          0.106480              0.271612
# superfluid                              0.098975              0.308692
# supernova                               0.082393              0.116114
# superstring theory                      0.072302              0.674630
# supersymmetry                           0.085154              0.603363
# surface physics                         1.000000              0.100714
# theory of everything                    0.100714              1.000000
# universe                                0.091458              0.341071
# vacuum energy                                NaN                   NaN
# vehicle dynamics                             NaN                   NaN
# weak                                         NaN                   NaN
#
#                                  universe  vacuum energy  vehicle dynamics  \
# Wilhelm Conrad Röntgen           0.100884            NaN               NaN
# Hendrik Lorentz                  0.165452            NaN               NaN
# Pieter Zeeman                    0.092422            NaN               NaN
# Antoine Henri Becquerel          0.108139            NaN               NaN
# Pierre Curie                     0.105708            NaN               NaN
# Maria Skłodowska-Curie           0.142642            NaN               NaN
# Lord Rayleigh                    0.116242            NaN               NaN
# Philipp Eduard Anton von Lenard  0.158576            NaN               NaN
# Joseph John Thomson              0.139934            NaN               NaN
# Albert Abraham Michelson         0.129082            NaN               NaN
# Gabriel Lippmann                 0.137005            NaN               NaN
# Guglielmo Marconi                0.143811            NaN               NaN
# Karl Ferdinand Braun             0.088983            NaN               NaN
# Johannes Diderik van der Waals   0.102934            NaN               NaN
# Wilhelm Wien                     0.131440            NaN               NaN
# Nils Gustaf Dalén                0.091297            NaN               NaN
# Heike Kamerlingh-Onnes           0.083880            NaN               NaN
# Max von Laue                     0.094970            NaN               NaN
# William Henry Bragg              0.108413            NaN               NaN
# William Lawrence Bragg           0.132298            NaN               NaN
# Charles Glover Barkla            0.110079            NaN               NaN
# Max Planck                       0.180165            NaN               NaN
# Johannes Stark                   0.093812            NaN               NaN
# Charles Édouard Guillaume        0.093808            NaN               NaN
# Albert Einstein                  0.268251            NaN               NaN
# Niels Bohr                       0.162929            NaN               NaN
# Robert Andrews Millikan          0.152009            NaN               NaN
# Manne Siegbahn                   0.092537            NaN               NaN
# James Franck                     0.162331            NaN               NaN
# Gustav Hertz                     0.084850            NaN               NaN
# ...                                   ...            ...               ...
# quantum optics                   0.139719            NaN               NaN
# seesaw mechanism                 0.136111            NaN               NaN
# self-organization                0.233664            NaN               NaN
# semiconductor                    0.170684            NaN               NaN
# solar physics                    0.193876            NaN               NaN
# solar system                     0.214959            NaN               NaN
# solid                            0.178157            NaN               NaN
# solid state physics              0.193037            NaN               NaN
# solid-state devices              0.193037            NaN               NaN
# space physics                    0.231021            NaN               NaN
# spectral line                    0.131771            NaN               NaN
# spin                             0.136361            NaN               NaN
# spontaneous symmetry breaking    0.139527            NaN               NaN
# standard model                   0.294356            NaN               NaN
# star                             0.244563            NaN               NaN
# statistical mechanics            0.144017            NaN               NaN
# stellar astrophysics             0.441698            NaN               NaN
# string                           0.116938            NaN               NaN
# strong                           0.188458            NaN               NaN
# superconductor                   0.171741            NaN               NaN
# superfluid                       0.194931            NaN               NaN
# supernova                        0.175400            NaN               NaN
# superstring theory               0.198123            NaN               NaN
# supersymmetry                    0.230712            NaN               NaN
# surface physics                  0.091458            NaN               NaN
# theory of everything             0.341071            NaN               NaN
# universe                         1.000000            NaN               NaN
# vacuum energy                         NaN            NaN               NaN
# vehicle dynamics                      NaN            NaN               NaN
# weak                                  NaN            NaN               NaN
#
#                                  weak
# Wilhelm Conrad Röntgen            NaN
# Hendrik Lorentz                   NaN
# Pieter Zeeman                     NaN
# Antoine Henri Becquerel           NaN
# Pierre Curie                      NaN
# Maria Skłodowska-Curie            NaN
# Lord Rayleigh                     NaN
# Philipp Eduard Anton von Lenard   NaN
# Joseph John Thomson               NaN
# Albert Abraham Michelson          NaN
# Gabriel Lippmann                  NaN
# Guglielmo Marconi                 NaN
# Karl Ferdinand Braun              NaN
# Johannes Diderik van der Waals    NaN
# Wilhelm Wien                      NaN
# Nils Gustaf Dalén                 NaN
# Heike Kamerlingh-Onnes            NaN
# Max von Laue                      NaN
# William Henry Bragg               NaN
# William Lawrence Bragg            NaN
# Charles Glover Barkla             NaN
# Max Planck                        NaN
# Johannes Stark                    NaN
# Charles Édouard Guillaume         NaN
# Albert Einstein                   NaN
# Niels Bohr                        NaN
# Robert Andrews Millikan           NaN
# Manne Siegbahn                    NaN
# James Franck                      NaN
# Gustav Hertz                      NaN
# ...                               ...
# quantum optics                    NaN
# seesaw mechanism                  NaN
# self-organization                 NaN
# semiconductor                     NaN
# solar physics                     NaN
# solar system                      NaN
# solid                             NaN
# solid state physics               NaN
# solid-state devices               NaN
# space physics                     NaN
# spectral line                     NaN
# spin                              NaN
# spontaneous symmetry breaking     NaN
# standard model                    NaN
# star                              NaN
# statistical mechanics             NaN
# stellar astrophysics              NaN
# string                            NaN
# strong                            NaN
# superconductor                    NaN
# superfluid                        NaN
# supernova                         NaN
# superstring theory                NaN
# supersymmetry                     NaN
# surface physics                   NaN
# theory of everything              NaN
# universe                          NaN
# vacuum energy                     NaN
# vehicle dynamics                  NaN
# weak                              NaN
#
# [339 rows x 339 columns]

# %% [markdown]
# We are now going to "melt" `similarity_df` into a long dataframe:
#
# >- We need to reset the index of `similarity_df` ([`pd.reset_index`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.reset_index.html))
# - Then we use the [`melt`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.melt.html) function to melt the dataframe. Use the resetted index as `id_vars`.

# %%
# TODO: reset the index and melt the dataframe
similarity_df =  similarity_df.reset_index()
melted_df = pd.melt(similarity_df, id_vars=['index'])

melted_df.columns = ["source", "target", "value"]
melted_df
# Out:
#                                  source                  target     value
# 0                Wilhelm Conrad Röntgen  Wilhelm Conrad Röntgen  1.000000
# 1                       Hendrik Lorentz  Wilhelm Conrad Röntgen  0.185980
# 2                         Pieter Zeeman  Wilhelm Conrad Röntgen  0.235582
# 3               Antoine Henri Becquerel  Wilhelm Conrad Röntgen  0.246754
# 4                          Pierre Curie  Wilhelm Conrad Röntgen  0.243904
# 5                Maria Skłodowska-Curie  Wilhelm Conrad Röntgen  0.264306
# 6                         Lord Rayleigh  Wilhelm Conrad Röntgen  0.279527
# 7       Philipp Eduard Anton von Lenard  Wilhelm Conrad Röntgen  0.322531
# 8                   Joseph John Thomson  Wilhelm Conrad Röntgen  0.271153
# 9              Albert Abraham Michelson  Wilhelm Conrad Röntgen  0.226106
# 10                     Gabriel Lippmann  Wilhelm Conrad Röntgen  0.195201
# 11                    Guglielmo Marconi  Wilhelm Conrad Röntgen  0.187961
# 12                 Karl Ferdinand Braun  Wilhelm Conrad Röntgen  0.238879
# 13       Johannes Diderik van der Waals  Wilhelm Conrad Röntgen  0.188112
# 14                         Wilhelm Wien  Wilhelm Conrad Röntgen  0.348077
# 15                    Nils Gustaf Dalén  Wilhelm Conrad Röntgen  0.272349
# 16               Heike Kamerlingh-Onnes  Wilhelm Conrad Röntgen  0.195516
# 17                         Max von Laue  Wilhelm Conrad Röntgen  0.206985
# 18                  William Henry Bragg  Wilhelm Conrad Röntgen  0.290272
# 19               William Lawrence Bragg  Wilhelm Conrad Röntgen  0.268874
# 20                Charles Glover Barkla  Wilhelm Conrad Röntgen  0.341671
# 21                           Max Planck  Wilhelm Conrad Röntgen  0.196423
# 22                       Johannes Stark  Wilhelm Conrad Röntgen  0.275262
# 23            Charles Édouard Guillaume  Wilhelm Conrad Röntgen  0.186343
# 24                      Albert Einstein  Wilhelm Conrad Röntgen  0.191417
# 25                           Niels Bohr  Wilhelm Conrad Röntgen  0.187483
# 26              Robert Andrews Millikan  Wilhelm Conrad Röntgen  0.213136
# 27                       Manne Siegbahn  Wilhelm Conrad Röntgen  0.307693
# 28                         James Franck  Wilhelm Conrad Röntgen  0.285756
# 29                         Gustav Hertz  Wilhelm Conrad Röntgen  0.229287
# ...                                 ...                     ...       ...
# 114891                   quantum optics                    weak       NaN
# 114892                 seesaw mechanism                    weak       NaN
# 114893                self-organization                    weak       NaN
# 114894                    semiconductor                    weak       NaN
# 114895                    solar physics                    weak       NaN
# 114896                     solar system                    weak       NaN
# 114897                            solid                    weak       NaN
# 114898              solid state physics                    weak       NaN
# 114899              solid-state devices                    weak       NaN
# 114900                    space physics                    weak       NaN
# 114901                    spectral line                    weak       NaN
# 114902                             spin                    weak       NaN
# 114903    spontaneous symmetry breaking                    weak       NaN
# 114904                   standard model                    weak       NaN
# 114905                             star                    weak       NaN
# 114906            statistical mechanics                    weak       NaN
# 114907             stellar astrophysics                    weak       NaN
# 114908                           string                    weak       NaN
# 114909                           strong                    weak       NaN
# 114910                   superconductor                    weak       NaN
# 114911                       superfluid                    weak       NaN
# 114912                        supernova                    weak       NaN
# 114913               superstring theory                    weak       NaN
# 114914                    supersymmetry                    weak       NaN
# 114915                  surface physics                    weak       NaN
# 114916             theory of everything                    weak       NaN
# 114917                         universe                    weak       NaN
# 114918                    vacuum energy                    weak       NaN
# 114919                 vehicle dynamics                    weak       NaN
# 114920                             weak                    weak       NaN
#
# [114921 rows x 3 columns]

# %% [markdown]
# You can see that at this point we have something close to what is necessary to create the links data. There are 3 things we need do to finalize our dataset. First, it is unnecessary to have "source" equal to the "target" (a node does not need to be linked to itself). Second, we have a duplicated links because in our case a "source" has the same role than a "target" and can be interchanged (our graph is not directed). Third, we need to subset the links set because there are too many for the program to run efficiently.
#
# Let's shuffle the data set rowwise ([`sample`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.sample.html)). This help us to not bias our links selection due to a prior alphabetic ordering of the data

# %%
melted_df = melted_df.sample(frac=1.).reset_index(drop=True)
melted_df
# Out:
#                               source  \
# 0             Philip Warren Anderson
# 1                       Pierre Curie
# 2                   Gabriel Lippmann
# 3                             optics
# 4            Antoine Henri Becquerel
# 5                   Leon Neil Cooper
# 6                        Felix Bloch
# 7         Subrahmanyan Chandrasekhar
# 8                    applied physics
# 9             Philip Warren Anderson
# 10                       Peter Higgs
# 11                     vacuum energy
# 12            William Lawrence Bragg
# 13                     Antony Hewish
# 14                  Makoto Kobayashi
# 15                        Paul Dirac
# 16                 Ben Roy Mottelson
# 17                     Antony Hewish
# 18              stellar astrophysics
# 19                Eric Allin Cornell
# 20                John M. Kosterlitz
# 21                           gravity
# 22           William Daniel Phillips
# 23            Heike Kamerlingh-Onnes
# 24                  seesaw mechanism
# 25           quantum electrodynamics
# 26                    Charles K. Kao
# 27              Arthur Holly Compton
# 28            Igor Yevgenyevich Tamm
# 29                      Dennis Gabor
# ...                              ...
# 114891               Ernest Lawrence
# 114892              Julian Schwinger
# 114893                    superfluid
# 114894              many-body theory
# 114895              Brian P. Schmidt
# 114896  Pavel Alekseyevich Cherenkov
# 114897                        cosmos
# 114898          neutrino oscillation
# 114899          lattice field theory
# 114900                plasma physics
# 114901              Daniel Chee Tsui
# 114902     electromagnetic radiation
# 114903   Charles Thomson Rees Wilson
# 114904          neutrino oscillation
# 114905                 Walther Bothe
# 114906                 Walther Bothe
# 114907                  Gustav Hertz
# 114908       Arthur Leonard Schawlow
# 114909        Walter Houser Brattain
# 114910            Bertram Brockhouse
# 114911             fundamental force
# 114912                        cosmos
# 114913          lattice gauge theory
# 114914                    Steven Chu
# 114915               Melvin Schwartz
# 114916       Percy Williams Bridgman
# 114917             J. Hans D. Jensen
# 114918                     Aage Bohr
# 114919                Polykarp Kusch
# 114920        Martinus J. G. Veltman
#
#                                                  target     value
# 0                               Antoine Henri Becquerel  0.167537
# 1                         spontaneous symmetry breaking  0.069079
# 2                                        Takaaki Kajita  0.255798
# 3                                       Saul Perlmutter  0.074754
# 4                                     Werner Heisenberg  0.165486
# 5                                         spectral line  0.062728
# 6                                            Steven Chu  0.263732
# 7                              John Hasbrouck Van Vleck  0.242608
# 8                        particle physics phenomenology  0.508666
# 9                                    Cecil Frank Powell  0.284631
# 10                                     Willard S. Boyle  0.301587
# 11                                       John C. Mather       NaN
# 12                                   Robert B. Laughlin  0.348173
# 13                                    Theodor W. Hänsch  0.340647
# 14                                     Makoto Kobayashi  1.000000
# 15                                       Johannes Stark  0.189683
# 16                               William Lawrence Bragg  0.400733
# 17                                               planet  0.091971
# 18                                     Jack Steinberger  0.154302
# 19                                       nanotechnology  0.117693
# 20                                      George E. Smith  0.553770
# 21                                  Charles Hard Townes  0.121385
# 22                             condensed matter physics  0.228514
# 23                               Heike Kamerlingh-Onnes  1.000000
# 24                            Joseph Hooton Taylor, Jr.  0.073553
# 25                                                 atom  0.297748
# 26                              gravitational radiation  0.114342
# 27                                   Eric Allin Cornell  0.251802
# 28                                 Karl Ferdinand Braun  0.242728
# 29                                               photon  0.171428
# ...                                                 ...       ...
# 114891                                  Hendrik Lorentz  0.167893
# 114892                                Emilio Gino Segrè  0.215147
# 114893                                        fermi gas  0.217741
# 114894                                            brane  0.151119
# 114895                                        supernova  0.135128
# 114896                                   John C. Mather  0.247860
# 114897                          Rudolf Ludwig Mössbauer  0.072357
# 114898                                  Albert Einstein  0.102271
# 114899                                     Wilhelm Wien  0.067412
# 114900                          low-temperature physics  0.141669
# 114901                                        astronomy  0.076774
# 114902                                materials physics  0.149473
# 114903                           John Douglas Cockcroft  0.286494
# 114904                             polarization (waves)  0.139317
# 114905                                    semiconductor  0.117757
# 114906                                 François Englert  0.292172
# 114907                                     gauge theory  0.052407
# 114908                           John Douglas Cockcroft  0.254197
# 114909                                  Albert Einstein  0.206834
# 114910                                  Herbert Kroemer  0.539209
# 114911                                   Burton Richter  0.115295
# 114912                                      Peter Higgs  0.125090
# 114913                              elementary particle  0.230263
# 114914                              solid state physics  0.185047
# 114915                         grand unification theory  0.098974
# 114916                              quantum electronics  0.092650
# 114917  Louis Victor Pierre Raymond, 7th Duc de Broglie  0.174168
# 114918                             nuclear astrophysics  0.193419
# 114919                                       Louis Néel  0.349641
# 114920                                    Hideki Yukawa  0.395691
#
# [114921 rows x 3 columns]

# %% [markdown]
# We then going to find the pairs of ("source", "target") that are equal to pairs ("target", "source"). To do that we are going to merge `melted_df` with itself where ("source", "target") = ("target", "source").
#
# >- merge it with itself with `left_on=["source", "target"]` and `right_on=["target", "source"]`. Pass the dataframe with the index resetted using [`pd.reset_index`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.reset_index.html).

# %%
# TODO: merge melted_df with itself
melted_df = melted_df.reset_index()
merged_df =  pd.merge(left=melted_df, right=melted_df, left_on=['source', 'target'], right_on=['target','source'])

merged_df
# Out:
#         index_x                      source_x  \
# 0             0        Philip Warren Anderson
# 1             1                  Pierre Curie
# 2             2              Gabriel Lippmann
# 3             3                        optics
# 4             4       Antoine Henri Becquerel
# 5             5              Leon Neil Cooper
# 6             6                   Felix Bloch
# 7             7    Subrahmanyan Chandrasekhar
# 8             8               applied physics
# 9             9        Philip Warren Anderson
# 10           10                   Peter Higgs
# 11           11                 vacuum energy
# 12           12        William Lawrence Bragg
# 13           13                 Antony Hewish
# 14           14              Makoto Kobayashi
# 15           15                    Paul Dirac
# 16           16             Ben Roy Mottelson
# 17           17                 Antony Hewish
# 18           18          stellar astrophysics
# 19           19            Eric Allin Cornell
# 20           20            John M. Kosterlitz
# 21           21                       gravity
# 22           22       William Daniel Phillips
# 23           23        Heike Kamerlingh-Onnes
# 24           24              seesaw mechanism
# 25           25       quantum electrodynamics
# 26           26                Charles K. Kao
# 27           27          Arthur Holly Compton
# 28           28        Igor Yevgenyevich Tamm
# 29           29                  Dennis Gabor
# ...         ...                           ...
# 114891   114891               Ernest Lawrence
# 114892   114892              Julian Schwinger
# 114893   114893                    superfluid
# 114894   114894              many-body theory
# 114895   114895              Brian P. Schmidt
# 114896   114896  Pavel Alekseyevich Cherenkov
# 114897   114897                        cosmos
# 114898   114898          neutrino oscillation
# 114899   114899          lattice field theory
# 114900   114900                plasma physics
# 114901   114901              Daniel Chee Tsui
# 114902   114902     electromagnetic radiation
# 114903   114903   Charles Thomson Rees Wilson
# 114904   114904          neutrino oscillation
# 114905   114905                 Walther Bothe
# 114906   114906                 Walther Bothe
# 114907   114907                  Gustav Hertz
# 114908   114908       Arthur Leonard Schawlow
# 114909   114909        Walter Houser Brattain
# 114910   114910            Bertram Brockhouse
# 114911   114911             fundamental force
# 114912   114912                        cosmos
# 114913   114913          lattice gauge theory
# 114914   114914                    Steven Chu
# 114915   114915               Melvin Schwartz
# 114916   114916       Percy Williams Bridgman
# 114917   114917             J. Hans D. Jensen
# 114918   114918                     Aage Bohr
# 4                                     Werner Heisenberg
# 5                                         spectral line
# 6                                            Steven Chu
# 7                              John Hasbrouck Van Vleck
# 8                        particle physics phenomenology
# 9                                    Cecil Frank Powell
# 10                                     Willard S. Boyle
# 11                                       John C. Mather
# 12                                   Robert B. Laughlin
# 13                                    Theodor W. Hänsch
# 14                                     Makoto Kobayashi
# 15                                       Johannes Stark
# 16                               William Lawrence Bragg
# 17                                               planet
# 18                                     Jack Steinberger
# 19                                       nanotechnology
# 20                                      George E. Smith
# 21                                  Charles Hard Townes
# 22                             condensed matter physics
# 23                               Heike Kamerlingh-Onnes
# 24                            Joseph Hooton Taylor, Jr.
# 25                                                 atom
# 26                              gravitational radiation
# 27                                   Eric Allin Cornell
# 28                                 Karl Ferdinand Braun
# 29                                               photon
# ...                                                 ...
# 114891                                  Hendrik Lorentz
# 114892                                Emilio Gino Segrè
# 114893                                        fermi gas
# 114894                                            brane
# 114895                                        supernova
# 114896                                   John C. Mather
# 114897                          Rudolf Ludwig Mössbauer
# 114898                                  Albert Einstein
# 114899                                     Wilhelm Wien
# 114900                          low-temperature physics
# 114901                                        astronomy
# 114902                                materials physics
# 114903                           John Douglas Cockcroft
# 114904                             polarization (waves)
# 114905                                    semiconductor
# 114906                                 François Englert
# 114907                                     gauge theory
# 114908                           John Douglas Cockcroft
# 114909                                  Albert Einstein
# 114910                                  Herbert Kroemer
# 114911                                   Burton Richter
# 114912                                      Peter Higgs
# 114913                              elementary particle
# 114914                              solid state physics
# 114915                         grand unification theory
# 114916                              quantum electronics
# 114917  Louis Victor Pierre Raymond, 7th Duc de Broglie
# 114918                             nuclear astrophysics
# 114919                                       Louis Néel
# 114920                                    Hideki Yukawa
#
#                             target_y   value_y
# 0             Philip Warren Anderson  0.167537
# 1                       Pierre Curie  0.069079
# 2                   Gabriel Lippmann  0.255798
# 3                             optics  0.074754
# 4            Antoine Henri Becquerel  0.165486
# 5                   Leon Neil Cooper  0.062728
# 6                        Felix Bloch  0.263732
# 7         Subrahmanyan Chandrasekhar  0.242608
# 8                    applied physics  0.508666
# 9             Philip Warren Anderson  0.284631
# 10                       Peter Higgs  0.301587
# 11                     vacuum energy       NaN
# 12            William Lawrence Bragg  0.348173
# 13                     Antony Hewish  0.340647
# 14                  Makoto Kobayashi  1.000000
# 15                        Paul Dirac  0.189683
# 16                 Ben Roy Mottelson  0.400733
# 17                     Antony Hewish  0.091971
# 18              stellar astrophysics  0.154302
# 19                Eric Allin Cornell  0.117693
# 20                John M. Kosterlitz  0.553770
# 21                           gravity  0.121385
# 22           William Daniel Phillips  0.228514
# 23            Heike Kamerlingh-Onnes  1.000000
# 24                  seesaw mechanism  0.073553
# 25           quantum electrodynamics  0.297748
# 26                    Charles K. Kao  0.114342
# 27              Arthur Holly Compton  0.251802
# 28            Igor Yevgenyevich Tamm  0.242728
# 29                      Dennis Gabor  0.171428
# ...                              ...       ...
# 114891               Ernest Lawrence  0.167893
# 114892              Julian Schwinger  0.215147
# 114893                    superfluid  0.217741
# 114894              many-body theory  0.151119
# 114895              Brian P. Schmidt  0.135128
# 114896  Pavel Alekseyevich Cherenkov  0.247860
# 114897                        cosmos  0.072357
# 114898          neutrino oscillation  0.102271
# 114899          lattice field theory  0.067412
# 114900                plasma physics  0.141669
# 114901              Daniel Chee Tsui  0.076774
# 114902     electromagnetic radiation  0.149473
# 114903   Charles Thomson Rees Wilson  0.286494
# 114904          neutrino oscillation  0.139317
# 114905                 Walther Bothe  0.117757
# 114906                 Walther Bothe  0.292172
# 114907                  Gustav Hertz  0.052407
# 114908       Arthur Leonard Schawlow  0.254197
# 114909        Walter Houser Brattain  0.206834
# 114910            Bertram Brockhouse  0.539209
# 114911             fundamental force  0.115295
# 114912                        cosmos  0.125090
# 114913          lattice gauge theory  0.230263
# 114914                    Steven Chu  0.185047
# 114915               Melvin Schwartz  0.098974
# 114916       Percy Williams Bridgman  0.092650
# 114917             J. Hans D. Jensen  0.174168
# 114918                     Aage Bohr  0.193419
# 114919                Polykarp Kusch  0.349641
# 114920        Martinus J. G. Veltman  0.395691
#
# [114921 rows x 8 columns]

# %% [markdown]
# At this point, we can see that each pair of ("source", "target") has the redondant equivalent ("target", "source"). This also highlight the cases where "source" = "target". To filter the useless rows we can simply pick the ("source", "target") pair or the ("target", "source") pick to remove. Let's choose which pair to remove by capturing the index we want to remove
#
# >- Look at the pair of columns `merged_df[["index_x", "index_y"]]` and simple choose the greater between the two using [`max`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.max.html). By selecting only the unique values ([`unique`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.unique.html)) of the resulting list of indices we have selected the index to remove and we can drop them using [`drop`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.drop.html).

# %%
# TODO: find the index to drop
index_to_drop =  merged_df[['index_x','index_y']].max(axis=1).unique()

# TODO: use the index_to_drop to subset the melted_df dataframe
melted_df_sub = merged_df.drop(index_to_drop)
melted_df_sub
# Out:
#         index_x                         source_x  \
# 0             0           Philip Warren Anderson
# 1             1                     Pierre Curie
# 2             2                 Gabriel Lippmann
# 3             3                           optics
# 4             4          Antoine Henri Becquerel
# 5             5                 Leon Neil Cooper
# 6             6                      Felix Bloch
# 7             7       Subrahmanyan Chandrasekhar
# 8             8                  applied physics
# 9             9           Philip Warren Anderson
# 10           10                      Peter Higgs
# 11           11                    vacuum energy
# 12           12           William Lawrence Bragg
# 13           13                    Antony Hewish
# 15           15                       Paul Dirac
# 16           16                Ben Roy Mottelson
# 17           17                    Antony Hewish
# 18           18             stellar astrophysics
# 19           19               Eric Allin Cornell
# 20           20               John M. Kosterlitz
# 21           21                          gravity
# 22           22          William Daniel Phillips
# 24           24                 seesaw mechanism
# 25           25          quantum electrodynamics
# 26           26                   Charles K. Kao
# 27           27             Arthur Holly Compton
# 28           28           Igor Yevgenyevich Tamm
# 29           29                     Dennis Gabor
# 30           30                    Frits Zernike
# 31           31      cosmic background radiation
# ...         ...                              ...
# 112575   112575                            solid
# 112688   112688                Martin Lewis Perl
# 112737   112737                       bloch wave
# 112738   112738                Erwin Schrödinger
# 112749   112749        gravitational singularity
# 112752   112752      Ernest Thomas Sinton Walton
# 112856   112856              Nevill Francis Mott
# 112940   112940           Edward Victor Appleton
# 113623       Joseph Hooton Taylor, Jr.                      dark energy
# 114058              Robert B. Laughlin              Sheldon Lee Glashow
# 114137                  Yoichiro Nambu               electroweak theory
# 114357          Philip Warren Anderson             stellar astrophysics
# 114451     Charles Thomson Rees Wilson           John Douglas Cockcroft
# 114565                          galaxy                     Carlo Rubbia
#
#          value_y
# 0       0.167537
# 1       0.069079
# 2       0.255798
# 3       0.074754
# 4       0.165486
# 5       0.062728
# 6       0.263732
# 7       0.242608
# 8       0.508666
# 9       0.284631
# 10      0.301587
# 11           NaN
# 12      0.348173
# 13      0.340647
# 15      0.189683
# 16      0.400733
# 17      0.091971
# 18      0.154302
# 19      0.117693
# 20      0.553770
# 21      0.121385
# 22      0.228514
# 24      0.073553
# 25      0.297748
# 26      0.114342
# 27      0.251802
# 28      0.242728
# 29      0.171428
# 30      0.351350
# 31      0.057000
# ...          ...
# 112575  0.062238
# 112688  0.329364
# 112737  0.060940
# 112738  0.183948
# 112749  0.148959
# 112752  0.070723
# 112856  0.120705
# 112940  0.275046
# 112977  0.179687
# 113027  0.108372
# 113112  0.104565
# 113137  0.062633
# 113149  0.292793
# 113152  0.232160
# 113235  0.539209
# 113242  0.233734
# 113252  0.354963
# 113256  0.201719
# 113301  0.066824
# 113316  0.127388
# 113373  0.093342
# 113410  0.262051
# 113467  0.386021
# 113510  0.114565
# 113623  0.111931
# 114058  0.432227
# 114137  0.145741
# 114357  0.135208
# 114451  0.286494
# 114565  0.114670
#
# [57291 rows x 8 columns]

# %% [markdown]
# We have filtered quite a bit of rows but it still is too many for the network simulation to run efficiently. For each source, we are going to select the 10 highest values.
#
# >- Group `melted_df_sub` by "source" using the [`groupby`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html) method and select the 10 targets that have the highest values using the [`nlargest`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.nlargest.html) method.
# - The resulting pandas Series has a multiindex with 2 levels. We need to get the level 1 of the multiindex to know which rows to keep in `melted_df_sub`. You can get it using the function [`get_level_values`](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Index.get_level_values.html) on the index.

# %%
# TODO: Group melted_df_sub by "source" using the groupby method and select the 10 
# targets that have the highest values using the nlargest method
largest_df =  melted_df_sub.groupby('source_x')['value_x'].nlargest(10)

# TODO: get the level 1 of the multiindex
index_to_keep =  largest_df.index.get_level_values(1)
links_df = melted_df_sub.loc[index_to_keep]
links_df
# Out:
#         index_x              source_x                                target_x  \
# 37985     37985             Aage Bohr                       Ben Roy Mottelson
# 59067     59067             Aage Bohr                     Leo James Rainwater
# 52003     52003             Aage Bohr                    Nicolaas Bloembergen
# 59769     59769             Aage Bohr                       Val Logsdon Fitch
# 1342       1342             Aage Bohr                      Jerome I. Friedman
# 46015     46015             Aage Bohr                              Andre Geim
# 88032     88032             Aage Bohr                Kai Manne Börje Siegbahn
# 12650     12650             Aage Bohr                      Bertram Brockhouse
# 22796     22796             Aage Bohr                          Yoichiro Nambu
# 81987     81987             Aage Bohr                       David J. Wineland
# 53893     53893           Abdus Salam                              Andre Geim
# 39423     39423           Abdus Salam                    Nicolaas Bloembergen
# 32648     32648           Abdus Salam                        François Englert
# 16884     16884           Abdus Salam                       Ben Roy Mottelson
# 3524       3524           Abdus Salam                   Anthony James Leggett
# 17566     17566           Abdus Salam                      Cecil Frank Powell
# 54230     54230           Abdus Salam                     Douglas D. Osheroff
# 27757     27757           Abdus Salam                          Takaaki Kajita
# 83582     83582           Abdus Salam                       Toshihide Maskawa
# 32022     32022           Abdus Salam                           Hiroshi Amano
# 49471     49471         Adam G. Riess                        Brian P. Schmidt
# 21364     21364         Adam G. Riess                          Takaaki Kajita
# 37328     37328         Adam G. Riess                       Riccardo Giacconi
# 24143     24143         Adam G. Riess                      Arthur B. McDonald
# 66164     66164         Adam G. Riess                              Andre Geim
# 84081     84081         Adam G. Riess                       David J. Thouless
# 15005     15005         Adam G. Riess                      John M. Kosterlitz
# 30519     30519         Adam G. Riess                      Bertram Brockhouse
# 9708       9708         Adam G. Riess                    Horst Ludwig Störmer
# 55659     55659         Adam G. Riess               Joseph Hooton Taylor, Jr.
# ...         ...                   ...                                     ...
# 49897     49897       surface physics                                molecule
# 7033       7033       surface physics                                   solid
# 1756       1756       surface physics                          nanotechnology
# 53478     53478       surface physics                       molecular physics
# 7651       7651       surface physics                            astrophysics
# 102526   102526       surface physics                              biophysics
# 1063       1063       surface physics  atomic, molecular, and optical physics
# 3113       3113       surface physics                                    atom
# 66880     66880       surface physics                  planetary astrophysics
# 23440     23440       surface physics                     solid-state devices
# 91746     91746  theory of everything                                m-theory
# 33991     33991  theory of everything                       fundamental force
# 7440       7440  theory of everything                  effective field theory
# 28027     28027  theory of everything                                 gravity
# 56905     56905  theory of everything                    quantum field theory
# 69778     69778  theory of everything                  quantum chromodynamics
# 107505   107505  theory of everything                 quantum electrodynamics
# 73202     73202  theory of everything                grand unification theory
# 25224     25224  theory of everything                     elementary particle
# 19934     19934  theory of everything                    lattice gauge theory
# 20100     20100              universe                        cosmic inflation
# 8194       8194              universe                             dark matter
# 24284     24284              universe                         George F. Smoot
# 5331       5331              universe             cosmic background radiation
# 36851     36851              universe                              antimatter
# 50000     50000              universe                                  galaxy
# 16934     16934              universe                            astrophysics
# 5890       5890              universe                     elementary particle
# 5772       5772              universe                                 gravity
# 41349     41349              universe                           gravitational
#
#          value_x  index_y                                source_y  \
# 37985   0.649636    45870                       Ben Roy Mottelson
# 59067   0.573598    90561                     Leo James Rainwater
# 52003   0.484146    81549                    Nicolaas Bloembergen
# 59769   0.466606    83125                       Val Logsdon Fitch
# 1342    0.434127   105573                      Jerome I. Friedman
# 46015   0.429708    89971                              Andre Geim
# 88032   0.427583   113744                Kai Manne Börje Siegbahn
# 12650   0.419082    71591                      Bertram Brockhouse
# 22796   0.415775    94382                          Yoichiro Nambu
# 81987   0.405996    92620                       David J. Wineland
# 53893   0.312172   103686                              Andre Geim
# 39423   0.304373   104028                    Nicolaas Bloembergen
# 32648   0.301761    76653                        François Englert
# 16884   0.301716    50194                       Ben Roy Mottelson
# 3524    0.300450    51166                   Anthony James Leggett
# 17566   0.290853    76280                      Cecil Frank Powell
# 54230   0.290498   101302                     Douglas D. Osheroff
# 7651         surface physics                            astrophysics  0.201436
# 102526       surface physics                              biophysics  0.200709
# 1063         surface physics  atomic, molecular, and optical physics  0.194553
# 3113         surface physics                                    atom  0.178218
# 66880        surface physics                  planetary astrophysics  0.176654
# 23440        surface physics                     solid-state devices  0.171862
# 91746   theory of everything                                m-theory  0.737124
# 33991   theory of everything                       fundamental force  0.654590
# 7440    theory of everything                  effective field theory  0.607495
# 28027   theory of everything                                 gravity  0.586095
# 56905   theory of everything                    quantum field theory  0.560926
# 69778   theory of everything                  quantum chromodynamics  0.494667
# 107505  theory of everything                 quantum electrodynamics  0.470917
# 73202   theory of everything                grand unification theory  0.469619
# 25224   theory of everything                     elementary particle  0.422850
# 19934   theory of everything                    lattice gauge theory  0.397604
# 20100               universe                        cosmic inflation  0.628593
# 8194                universe                             dark matter  0.505898
# 24284               universe                         George F. Smoot  0.396809
# 5331                universe             cosmic background radiation  0.390731
# 36851               universe                              antimatter  0.377286
# 50000               universe                                  galaxy  0.360143
# 16934               universe                            astrophysics  0.353643
# 5890                universe                     elementary particle  0.349788
# 5772                universe                                 gravity  0.348517
# 41349               universe                           gravitational  0.348517
#
# [3360 rows x 3 columns]

# %% [markdown]
# We need to cast this data frame as a list of dictionaries as we have done for the list of nodes.
#
# >Use a similar code to than for the nodes to create a list of links:

# %%
# TODO: create the list of links
links_list =  list(links_df2.transpose().to_dict().values())
links_list
# Out:
# [{'source': 'Aage Bohr',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.6496358338199949},
#  {'source': 'Aage Bohr',
#   'target': 'Leo James Rainwater',
#   'value': 0.5735984893350551},
#  {'source': 'Aage Bohr',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.48414552726817844},
#  {'source': 'Aage Bohr',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.46660587882502436},
#  {'source': 'Aage Bohr',
#   'target': 'Jerome I. Friedman',
#   'value': 0.43412684404660457},
#  {'source': 'Aage Bohr', 'target': 'Andre Geim', 'value': 0.42970797701864916},
#  {'source': 'Aage Bohr',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.42758271079183063},
#  {'source': 'Aage Bohr',
#   'target': 'Bertram Brockhouse',
#   'value': 0.41908191993562294},
#  {'source': 'Aage Bohr',
#   'target': 'Yoichiro Nambu',
#   'value': 0.41577494725922026},
#  {'source': 'Aage Bohr',
#   'target': 'David J. Wineland',
#   'value': 0.40599597458476433},
#  {'source': 'Abdus Salam', 'target': 'Andre Geim', 'value': 0.312172016599622},
#  {'source': 'Abdus Salam',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.30437256482066477},
#  {'source': 'Abdus Salam',
#   'target': 'François Englert',
#   'value': 0.301761434946279},
#  {'source': 'Abdus Salam',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.3017160487448492},
#  {'source': 'Abdus Salam',
#   'target': 'Anthony James Leggett',
#   'value': 0.3004503315802836},
#  {'source': 'Abdus Salam',
#   'target': 'Cecil Frank Powell',
#   'value': 0.29085318696172857},
#  {'source': 'Abdus Salam',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.29049799893041317},
#  {'source': 'Abdus Salam',
#   'target': 'Takaaki Kajita',
#   'value': 0.28179805203757946},
#  {'source': 'Abdus Salam',
#   'target': 'Toshihide Maskawa',
#   'value': 0.28170564664411857},
#  {'source': 'Abdus Salam',
#   'target': 'Hiroshi Amano',
#   'value': 0.28160263091396864},
#  {'source': 'Adam G. Riess',
#   'target': 'Brian P. Schmidt',
#   'value': 0.6584041366565281},
#  {'source': 'Adam G. Riess',
#   'target': 'Takaaki Kajita',
#   'value': 0.5385693462920748},
#  {'source': 'Adam G. Riess',
#   'target': 'Riccardo Giacconi',
#   'value': 0.5305331540696873},
#  {'source': 'Adam G. Riess',
#   'target': 'Arthur B. McDonald',
#   'value': 0.47361793736092567},
#  {'source': 'Adam G. Riess',
#   'target': 'Andre Geim',
#   'value': 0.4718222456698345},
#  {'source': 'Adam G. Riess',
#   'target': 'David J. Thouless',
#   'value': 0.4715852835365918},
#  {'source': 'Adam G. Riess',
#   'target': 'John M. Kosterlitz',
#   'value': 0.4623019783536844},
#  {'source': 'Adam G. Riess',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4617083339197007},
#  {'source': 'Adam G. Riess',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.4607923898577429},
#  {'source': 'Adam G. Riess',
#   'target': 'Joseph Hooton Taylor, Jr.',
#   'value': 0.45012177202854525},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.44945761848659244},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'John Robert Schrieffer',
#   'value': 0.4392373098879807},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Frederick Reines',
#   'value': 0.4350406316910243},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Jerome I. Friedman',
#   'value': 0.4128051122075305},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Arthur Leonard Schawlow',
#   'value': 0.4092808481428113},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Chen Ning Yang',
#   'value': 0.40288033671402235},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'William Alfred Fowler',
#   'value': 0.3974713704282306},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Burton Richter',
#   'value': 0.374614072101665},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Robert Andrews Millikan',
#   'value': 0.37134751830081975},
#  {'source': 'Albert Abraham Michelson',
#   'target': 'Riccardo Giacconi',
#   'value': 0.36465549253157326},
#  {'source': 'Albert Einstein',
#   'target': 'Hendrik Lorentz',
#   'value': 0.38210720166725964},
#  {'source': 'Albert Einstein',
#   'target': 'theory of everything',
#   'value': 0.34150288049040173},
#  {'source': 'Albert Einstein',
#   'target': 'photon',
#   'value': 0.3295580550859274},
#  {'source': 'Albert Einstein',
#   'target': 'gravity',
#   'value': 0.3247555587362874},
#  {'source': 'Albert Einstein',
#   'target': 'gravitational',
#   'value': 0.3247555587362874},
#  {'source': 'Albert Einstein',
#   'target': 'Kip Thorne',
#   'value': 0.32111010686594854},
#  {'source': 'Albert Einstein',
#   'target': 'cosmology',
#   'value': 0.3017560759975719},
#  {'source': 'Albert Einstein',
#   'target': 'James Franck',
#   'value': 0.28701984824063287},
#  {'source': 'Albert Einstein',
#   'target': 'condensed matter physics',
#   'value': 0.28203354384550194},
#  {'source': 'Albert Einstein',
#   'target': 'Paul Dirac',
#   'value': 0.2816909011514611},
#  {'source': 'Albert Fert',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.6679720485488008},
#  {'source': 'Albert Fert',
#   'target': 'Peter Grünberg',
#   'value': 0.6384692621869882},
#  {'source': 'Albert Fert',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.6212698523641721},
#  {'source': 'Albert Fert',
#   'target': 'François Englert',
#   'value': 0.5889263160855547},
#  {'source': 'Albert Fert',
#   'target': 'David J. Thouless',
#   'value': 0.5766449609072503},
#  {'source': 'Albert Fert',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.5519066981187135},
#  {'source': 'Albert Fert',
#   'target': 'David Morris Lee',
#   'value': 0.5513922000913849},
#  {'source': 'Albert Fert',
#   'target': 'Martin Lewis Perl',
#   'value': 0.5503136702538728},
#  {'source': 'Albert Fert',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.5411215810797848},
#  {'source': 'Albert Fert',
#   'target': 'Robert B. Laughlin',
#   'value': 0.5346453475066871},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Nicolay Gennadiyevich Basov',
#   'value': 0.6543573033199788},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Zhores Ivanovich Alferov',
#   'value': 0.5628314078085193},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Ilya Frank',
#   'value': 0.47279376038869886},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Andre Geim',
#   'value': 0.4529758101675793},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Konstantin Novoselov',
#   'value': 0.4507305848676891},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Theodor W. Hänsch',
#   'value': 0.43324401692855724},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Manne Siegbahn',
#   'value': 0.4304015469391596},
#  {'source': 'Alexander Prokhorov',
#   'target': 'John L. Hall',
#   'value': 0.4248053821890909},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Igor Yevgenyevich Tamm',
#   'value': 0.4243172641572074},
#  {'source': 'Alexander Prokhorov',
#   'target': 'Hiroshi Amano',
#   'value': 0.42217453381516157},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.5295736635697887},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Alexander Prokhorov',
#   'value': 0.4807688094269459},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.4775797251594524},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4695456847012435},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Riccardo Giacconi',
#   'value': 0.468719099405655},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Eric Allin Cornell',
#   'value': 0.46708139353271083},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Leon Neil Cooper',
#   'value': 0.45106249380923663},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.4494025636067145},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.4472093373172966},
#  {'source': 'Alexei Alexeyevich Abrikosov',
#   'target': 'Herbert Kroemer',
#   'value': 0.44351945299398254},
#  {'source': 'Alfred Kastler',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.46865496882689606},
#  {'source': 'Alfred Kastler',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.45552895267297794},
#  {'source': 'Alfred Kastler',
#   'target': 'Hans Georg Dehmelt',
#   'value': 0.4418842562371377},
#  {'source': 'Alfred Kastler',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4387932161564458},
#  {'source': 'Alfred Kastler',
#   'target': 'Wolfgang Paul',
#   'value': 0.4341604183557454},
#  {'source': 'Alfred Kastler',
#   'target': 'Nicolay Gennadiyevich Basov',
#   'value': 0.43360311519454264},
#  {'source': 'Alfred Kastler',
#   'target': 'Owen Willans Richardson',
#   'value': 0.42875707214742054},
#  {'source': 'Alfred Kastler',
#   'target': 'David Morris Lee',
#   'value': 0.42500972325706526},
#  {'source': 'Alfred Kastler',
#   'target': 'Polykarp Kusch',
#   'value': 0.421990967018805},
#  {'source': 'Alfred Kastler',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.4164941742840312},
#  {'source': 'Andre Geim',
#   'target': 'Takaaki Kajita',
#   'value': 0.638504991017356},
#  {'source': 'Andre Geim',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.5959139701554551},
#  {'source': 'Andre Geim',
#   'target': 'Isamu Akasaki',
#   'value': 0.5768480225874785},
#  {'source': 'Andre Geim',
#   'target': 'Manne Siegbahn',
#   'value': 0.5546319763977393},
#  {'source': 'Andre Geim',
#   'target': 'Hiroshi Amano',
#   'value': 0.5526435495614653},
#  {'source': 'Andre Geim',
#   'target': 'Charles K. Kao',
#   'value': 0.5463122520539985},
#  {'source': 'Andre Geim',
#   'target': 'Toshihide Maskawa',
#   'value': 0.5317406880395078},
#  {'source': 'Andre Geim',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.5219437846353444},
#  {'source': 'Andre Geim',
#   'target': 'John L. Hall',
#   'value': 0.5165594246596975},
#  {'source': 'Andre Geim',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.5143111844914479},
#  {'source': 'Anthony James Leggett',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5796728423165538},
#  {'source': 'Anthony James Leggett',
#   'target': 'John M. Kosterlitz',
#   'value': 0.5632762713560594},
#  {'source': 'Anthony James Leggett',
#   'target': 'Albert Fert',
#   'value': 0.5217945320169045},
#  {'source': 'Anthony James Leggett',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5197328422536113},
#  {'source': 'Anthony James Leggett',
#   'target': 'Hiroshi Amano',
#   'value': 0.5091834467328826},
#  {'source': 'Anthony James Leggett',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.5072663495624936},
#  {'source': 'Anthony James Leggett',
#   'target': 'Leon Neil Cooper',
#   'value': 0.49777620826045166},
#  {'source': 'Anthony James Leggett',
#   'target': 'Toshihide Maskawa',
#   'value': 0.49633655782829234},
#  {'source': 'Anthony James Leggett',
#   'target': 'Eric Allin Cornell',
#   'value': 0.4923969208408312},
#  {'source': 'Anthony James Leggett',
#   'target': 'Alexei Alexeyevich Abrikosov',
#   'value': 0.4899699606827576},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Jean Baptiste Perrin',
#   'value': 0.3590335512240546},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.3589977318311561},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Pierre Curie',
#   'value': 0.3101113131132078},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Carl David Anderson',
#   'value': 0.26856740447027455},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Frits Zernike',
#   'value': 0.26742270132843987},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.26029577986113434},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Manne Siegbahn',
#   'value': 0.25942175105625875},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Pavel Alekseyevich Cherenkov',
#   'value': 0.25763021522207435},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Pieter Zeeman',
#   'value': 0.25731499720731255},
#  {'source': 'Antoine Henri Becquerel',
#   'target': 'Nicolay Gennadiyevich Basov',
#   'value': 0.25414253309266915},
#  {'source': 'Antony Hewish',
#   'target': 'Martin Ryle',
#   'value': 0.557672222709269},
#  {'source': 'Antony Hewish',
#   'target': 'Owen Willans Richardson',
#   'value': 0.46130230382874493},
#  {'source': 'Antony Hewish',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4428082496091447},
#  {'source': 'Antony Hewish',
#   'target': 'Manne Siegbahn',
#   'value': 0.4417292061488845},
#  {'source': 'Antony Hewish',
#   'target': 'Andre Geim',
#   'value': 0.4386662468145836},
#  {'source': 'Antony Hewish',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.42296635351660744},
#  {'source': 'Antony Hewish',
#   'target': 'Dennis Gabor',
#   'value': 0.41964212987439653},
#  {'source': 'Antony Hewish',
#   'target': 'Hiroshi Amano',
#   'value': 0.41767489749270675},
#  {'source': 'Antony Hewish',
#   'target': 'Riccardo Giacconi',
#   'value': 0.40894018239742913},
#  {'source': 'Antony Hewish',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.4079043390613467},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Robert Woodrow Wilson',
#   'value': 0.6670113083477883},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.3770451093012401},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.3744779936634443},
#  {'source': 'Arno Allan Penzias',
#   'target': 'big bang',
#   'value': 0.37216984201115466},
#  {'source': 'Arno Allan Penzias',
#   'target': 'John C. Mather',
#   'value': 0.3721449200507565},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Leon Neil Cooper',
#   'value': 0.3589564003962304},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Melvin Schwartz',
#   'value': 0.3516543503807001},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Antony Hewish',
#   'value': 0.3473653259475406},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Brian P. Schmidt',
#   'value': 0.3466521807006079},
#  {'source': 'Arno Allan Penzias',
#   'target': 'Riccardo Giacconi',
#   'value': 0.33945996192528216},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Takaaki Kajita',
#   'value': 0.6877988679326612},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.542769553168662},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Riccardo Giacconi',
#   'value': 0.507081361896124},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Frederick Reines',
#   'value': 0.5061844843896364},
#  {'source': 'Arthur B. McDonald',
#   'target': 'John M. Kosterlitz',
#   'value': 0.5040984768576764},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Andre Geim',
#   'value': 0.5035348328089537},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Manne Siegbahn',
#   'value': 0.48490229552751835},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4831311705683731},
#  {'source': 'Arthur B. McDonald',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.47977258117947863},
#  {'source': 'Arthur B. McDonald',
#   'target': 'David J. Wineland',
#   'value': 0.4787957492778675},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.3937976411056896},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Arthur Leonard Schawlow',
#   'value': 0.3911657232271559},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Robert Hofstadter',
#   'value': 0.38875044041299217},
#  {'source': 'Arthur Holly Compton',
#   'target': 'James Franck',
#   'value': 0.38270322408574636},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Frederick Reines',
#   'value': 0.37319487329878753},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Percy Williams Bridgman',
#   'value': 0.3563005592864588},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Eugene Paul Wigner',
#   'value': 0.35486663720154943},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Jerome I. Friedman',
#   'value': 0.34580408601579415},
#  {'source': 'Arthur Holly Compton',
#   'target': 'John Douglas Cockcroft',
#   'value': 0.3443017919480387},
#  {'source': 'Arthur Holly Compton',
#   'target': 'Yoichiro Nambu',
#   'value': 0.3374629238061712},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.5747252854868815},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Edward Mills Purcell',
#   'value': 0.49804325446424286},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Percy Williams Bridgman',
#   'value': 0.46857699182505447},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.46258805525204255},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Yoichiro Nambu',
#   'value': 0.45072839054517466},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Theodor W. Hänsch',
#   'value': 0.4473820680987283},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Burton Richter',
#   'value': 0.4419718994403665},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Arthur B. McDonald',
#   'value': 0.4238835024077957},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'John Hasbrouck Van Vleck',
#   'value': 0.42236836342915013},
#  {'source': 'Arthur Leonard Schawlow',
#   'target': 'Jack St. Clair Kilby',
#   'value': 0.4165836592748649},
#  {'source': 'Barry Barish',
#   'target': 'Rainer Weiss',
#   'value': 0.557328583499386},
#  {'source': 'Barry Barish',
#   'target': 'Andre Geim',
#   'value': 0.5376215447111977},
#  {'source': 'Barry Barish',
#   'target': 'Jerome I. Friedman',
#   'value': 0.5192171943250949},
#  {'source': 'Barry Barish',
#   'target': 'Takaaki Kajita',
#   'value': 0.5185944067869869},
#  {'source': 'Barry Barish',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.5003281810725638},
#  {'source': 'Barry Barish',
#   'target': 'Riccardo Giacconi',
#   'value': 0.4998433088579503},
#  {'source': 'Barry Barish',
#   'target': 'David J. Thouless',
#   'value': 0.4909147692049704},
#  {'source': 'Barry Barish',
#   'target': 'Konstantin Novoselov',
#   'value': 0.47666964089770664},
#  {'source': 'Barry Barish',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.4727041843711526},
#  {'source': 'Barry Barish',
#   'target': 'Joseph Hooton Taylor, Jr.',
#   'value': 0.465092292607919},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.5955555555555555},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.5698391208054643},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Leo James Rainwater',
#   'value': 0.5654801507283681},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Manne Siegbahn',
#   'value': 0.5608973537524075},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5499932751768207},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Frits Zernike',
#   'value': 0.5388844499152952},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Hiroshi Amano',
#   'value': 0.5307565201296455},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Makoto Kobayashi',
#   'value': 0.5287032163413391},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.5278500175482057},
#  {'source': 'Ben Roy Mottelson',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.526734582487565},
#  {'source': 'Bertram Brockhouse',
#   'target': 'John M. Kosterlitz',
#   'value': 0.6242900690368622},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.6158870365404725},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Riccardo Giacconi',
#   'value': 0.6143198053682865},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Richard E. Taylor',
#   'value': 0.6003725755801373},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.5973270765622343},
#  {'source': 'Bertram Brockhouse',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.5917683670973625},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Andre Geim',
#   'value': 0.5859659208111951},
#  {'source': 'Bertram Brockhouse',
#   'target': 'David Morris Lee',
#   'value': 0.578976284030514},
#  {'source': 'Bertram Brockhouse',
#   'target': 'George E. Smith',
#   'value': 0.571231932857303},
#  {'source': 'Bertram Brockhouse',
#   'target': 'Willard S. Boyle',
#   'value': 0.5697706438635014},
#  {'source': 'Brian David Josephson',
#   'target': 'Andre Geim',
#   'value': 0.43177429712613014},
#  {'source': 'Brian David Josephson',
#   'target': 'Anthony James Leggett',
#   'value': 0.43131007178793723},
#  {'source': 'Brian David Josephson',
#   'target': 'Konstantin Novoselov',
#   'value': 0.41515635497435815},
#  {'source': 'Brian David Josephson',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4148533371340535},
#  {'source': 'Brian David Josephson',
#   'target': 'condensed matter physics',
#   'value': 0.4087682513720784},
#  {'source': 'Brian David Josephson',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.39714228772430127},
#  {'source': 'Brian David Josephson',
#   'target': 'Hiroshi Amano',
#   'value': 0.39647792880470994},
#  {'source': 'Brian David Josephson',
#   'target': 'John M. Kosterlitz',
#   'value': 0.38672880103445995},
#  {'source': 'Brian David Josephson',
#   'target': 'Leon Neil Cooper',
#   'value': 0.3858946225420062},
#  {'source': 'Brian David Josephson',
#   'target': 'Isamu Akasaki',
#   'value': 0.3819314001761901},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Saul Perlmutter',
#   'value': 0.6183344433831527},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Andre Geim',
#   'value': 0.48162723928960727},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4412683821323773},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Konstantin Novoselov',
#   'value': 0.4296420718797677},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Riccardo Giacconi',
#   'value': 0.4275203407148389},
#  {'source': 'Brian P. Schmidt',
#   'target': 'Rainer Weiss',
#   'value': 0.41302911047686197},
#  {'source': 'Brian P. Schmidt',
#   'target': 'David J. Thouless',
#   'value': 0.40445551625305837},
#  {'source': 'Brian P. Schmidt',
#   'target': 'George F. Smoot',
#   'value': 0.3993736504813176},
#  {'source': 'Brian P. Schmidt',
#   'target': 'John L. Hall',
#   'value': 0.39637376520890233},
#  {'source': 'Brian P. Schmidt',
#   'target': 'David J. Wineland',
#   'value': 0.3951266778803745},
#  {'source': 'Burton Richter',
#   'target': 'Richard E. Taylor',
#   'value': 0.5458472582225556},
#  {'source': 'Burton Richter',
#   'target': 'Melvin Schwartz',
#   'value': 0.49012474259933614},
#  {'source': 'Burton Richter',
#   'target': 'John Robert Schrieffer',
#   'value': 0.48603679489806273},
#  {'source': 'Burton Richter',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4772303595675173},
#  {'source': 'Burton Richter',
#   'target': 'David J. Wineland',
#   'value': 0.45666437686826167},
#  {'source': 'Burton Richter',
#   'target': 'Robert B. Laughlin',
#   'value': 0.45163048041278325},
#  {'source': 'Burton Richter',
#   'target': 'Eric Allin Cornell',
#   'value': 0.436714407802251},
#  {'source': 'Burton Richter',
#   'target': 'Yoichiro Nambu',
#   'value': 0.4349629801196962},
#  {'source': 'Burton Richter',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.4320403188305879},
#  {'source': 'Burton Richter',
#   'target': 'Felix Bloch',
#   'value': 0.42662205927325425},
#  {'source': 'Carl David Anderson',
#   'target': 'Philip Warren Anderson',
#   'value': 0.598501605108721},
#  {'source': 'Carl David Anderson',
#   'target': 'Hugh David Politzer',
#   'value': 0.46227517330626317},
#  {'source': 'Carl David Anderson',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.45452166120921333},
#  {'source': 'Carl David Anderson',
#   'target': 'Eric Allin Cornell',
#   'value': 0.4387870220034782},
#  {'source': 'Carl David Anderson',
#   'target': 'Frits Zernike',
#   'value': 0.42610171094809296},
#  {'source': 'Carl David Anderson',
#   'target': 'Toshihide Maskawa',
#   'value': 0.42345714467455453},
#  {'source': 'Carl David Anderson',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4084007639620213},
#  {'source': 'Carl David Anderson',
#   'target': 'Riccardo Giacconi',
#   'value': 0.40666355749202615},
#  {'source': 'Carl David Anderson',
#   'target': 'Herbert Kroemer',
#   'value': 0.4003203845127179},
#  {'source': 'Carl David Anderson',
#   'target': 'Hiroshi Amano',
#   'value': 0.40012979650719405},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.504567681515542},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Wolfgang Ketterle',
#   'value': 0.5019365111035351},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.4993158077733019},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.495706783756376},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Hiroshi Amano',
#   'value': 0.49028621285861806},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Robert B. Laughlin',
#   'value': 0.48344452608572785},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Richard E. Taylor',
#   'value': 0.47079750462031345},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'David J. Thouless',
#   'value': 0.4655077588624114},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'John L. Hall',
#   'value': 0.4596982353102247},
#  {'source': 'Carl Edwin Wieman',
#   'target': 'Russell Alan Hulse',
#   'value': 0.44972999989067386},
#  {'source': 'Carlo Rubbia',
#   'target': 'particle physics',
#   'value': 0.391808254757507},
#  {'source': 'Carlo Rubbia',
#   'target': 'Jack Steinberger',
#   'value': 0.38596867036887783},
#  {'source': 'Carlo Rubbia',
#   'target': 'Makoto Kobayashi',
#   'value': 0.37310058844867855},
#  {'source': 'Carlo Rubbia',
#   'target': 'Toshihide Maskawa',
#   'value': 0.37276217588731686},
#  {'source': 'Carlo Rubbia',
#   'target': 'Richard E. Taylor',
#   'value': 0.3667350033031401},
#  {'source': 'Carlo Rubbia',
#   'target': 'Bertram Brockhouse',
#   'value': 0.35519709449098674},
#  {'source': 'Carlo Rubbia',
#   'target': 'Hiroshi Amano',
#   'value': 0.3496080021494526},
#  {'source': 'Carlo Rubbia',
#   'target': 'Roy J. Glauber',
#   'value': 0.34452596409716063},
#  {'source': 'Carlo Rubbia',
#   'target': 'Robert Hofstadter',
#   'value': 0.3350705147526033},
#  {'source': 'Carlo Rubbia',
#   'target': 'Burton Richter',
#   'value': 0.33132074626239705},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.46961574703847875},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4559585983285626},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Ilya Frank',
#   'value': 0.4473665210346565},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Bertram Brockhouse',
#   'value': 0.43137615351930125},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Georges Charpak',
#   'value': 0.4306984796214302},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.42490590297972086},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Riccardo Giacconi',
#   'value': 0.403473570028079},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Andre Geim',
#   'value': 0.3997248452436324},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Charles Glover Barkla',
#   'value': 0.39766082126857843},
#  {'source': 'Cecil Frank Powell',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.39717664981420125},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Andre Geim',
#   'value': 0.36090508195221727},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Manne Siegbahn',
#   'value': 0.3402533456442888},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Takaaki Kajita',
#   'value': 0.334104924705725},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.3232608757728126},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Hiroshi Amano',
#   'value': 0.31817739804182815},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'John L. Hall',
#   'value': 0.315934556230198},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.31204834013442484},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Frits Zernike',
#   'value': 0.3108088028825477},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.3091303732727651},
#  {'source': 'Chandrasekhara Venkata Raman',
#   'target': 'Roy J. Glauber',
#   'value': 0.30174345766312655},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Owen Willans Richardson',
#   'value': 0.561561114591613},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Manne Siegbahn',
#   'value': 0.5374401267349651},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4968429784739487},
#  {'source': 'Charles Glover Barkla',
#   'target': 'John M. Kosterlitz',
#   'value': 0.4941009265468664},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Antony Hewish',
#   'value': 0.4797410852564528},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Riccardo Giacconi',
#   'value': 0.4677127426217224},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Frits Zernike',
#   'value': 0.46221510450049424},
#  {'source': 'Charles Glover Barkla',
#   'target': 'Anthony James Leggett',
#   'value': 0.45710834551406687},
#  {'source': 'Charles Glover Barkla',
#   'target': 'David J. Thouless',
#   'value': 0.4526913086539228},
#  {'source': 'Charles Glover Barkla',
#   'target': 'David Morris Lee',
#   'value': 0.4513403145637938},
#  {'source': 'Charles Hard Townes',
#   'target': 'Arthur Leonard Schawlow',
#   'value': 0.5552647392466105},
#  {'source': 'Charles Hard Townes',
#   'target': 'Jack St. Clair Kilby',
#   'value': 0.4673039718950603},
#  {'source': 'Charles Hard Townes',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.45717129347069974},
#  {'source': 'Charles Hard Townes',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.4530876620626273},
#  {'source': 'Charles Hard Townes',
#   'target': 'John Robert Schrieffer',
#   'value': 0.4324741660731896},
#  {'source': 'Charles Hard Townes',
#   'target': 'Barry Barish',
#   'value': 0.4147421560280265},
#  {'source': 'Charles Hard Townes',
#   'target': 'Alexander Prokhorov',
#   'value': 0.40735691992642437},
#  {'source': 'Charles Hard Townes',
#   'target': 'John L. Hall',
#   'value': 0.40663687260107506},
#  {'source': 'Charles Hard Townes',
#   'target': 'John Hasbrouck Van Vleck',
#   'value': 0.402474379794349},
#  {'source': 'Charles Hard Townes',
#   'target': 'Albert Abraham Michelson',
#   'value': 0.3995637973909491},
#  {'source': 'Charles K. Kao',
#   'target': 'Konstantin Novoselov',
#   'value': 0.4839206843232462},
#  {'source': 'Charles K. Kao',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.458799123609471},
#  {'source': 'Charles K. Kao',
#   'target': 'Chen Ning Yang',
#   'value': 0.4293826849114188},
#  {'source': 'Charles K. Kao',
#   'target': 'Takaaki Kajita',
#   'value': 0.4142304477525098},
#  {'source': 'Charles K. Kao',
#   'target': 'David J. Thouless',
#   'value': 0.4022471051686372},
#  {'source': 'Charles K. Kao',
#   'target': 'Bertram Brockhouse',
#   'value': 0.39979462189392995},
#  {'source': 'Charles K. Kao',
#   'target': 'Dennis Gabor',
#   'value': 0.39416781554173896},
#  {'source': 'Charles K. Kao',
#   'target': 'Shuji Nakamura',
#   'value': 0.3924190181164819},
#  {'source': 'Charles K. Kao',
#   'target': 'Charles Hard Townes',
#   'value': 0.3855765558907548},
#  {'source': 'Charles K. Kao',
#   'target': 'Wolfgang Ketterle',
#   'value': 0.38102369076400916},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Kenneth G. Wilson',
#   'value': 0.5549098004215561},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Charles Glover Barkla',
#   'value': 0.5241348368834153},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Robert Woodrow Wilson',
#   'value': 0.4936733649226927},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'George Paget Thomson',
#   'value': 0.47545676501173023},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Owen Willans Richardson',
#   'value': 0.44940938004032915},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.4125821857344154},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.3879857363375046},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Frits Zernike',
#   'value': 0.37252106664618434},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Cecil Frank Powell',
#   'value': 0.3713297467213818},
#  {'source': 'Charles Thomson Rees Wilson',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.36082934372739683},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Jean Baptiste Perrin',
#   'value': 0.3660265200153193},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Robert B. Laughlin',
#   'value': 0.3629575660893187},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Manne Siegbahn',
#   'value': 0.34192312130831165},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Gabriel Lippmann',
#   'value': 0.3343565330899798},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Riccardo Giacconi',
#   'value': 0.33320678171622303},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Bertram Brockhouse',
#   'value': 0.3322000982919287},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Frits Zernike',
#   'value': 0.3252097483493036},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'William Daniel Phillips',
#   'value': 0.31918949365414834},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Clinton Joseph Davisson',
#   'value': 0.315770807994262},
#  {'source': 'Charles Édouard Guillaume',
#   'target': 'Ernst Ruska',
#   'value': 0.3123285726256635},
#  {'source': 'Chen Ning Yang',
#   'target': 'David J. Wineland',
#   'value': 0.6294020137607289},
#  {'source': 'Chen Ning Yang',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.5875568261016854},
#  {'source': 'Chen Ning Yang',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.558852146272881},
#  {'source': 'Chen Ning Yang',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.5150666541768646},
#  {'source': 'Chen Ning Yang',
#   'target': 'Jerome I. Friedman',
#   'value': 0.4727280280813998},
#  {'source': 'Chen Ning Yang',
#   'target': 'David J. Gross',
#   'value': 0.45766293056864604},
#  {'source': 'Chen Ning Yang',
#   'target': 'John M. Kosterlitz',
#   'value': 0.4361605300556999},
#  {'source': 'Chen Ning Yang',
#   'target': 'Edward Mills Purcell',
#   'value': 0.42456636185442326},
#  {'source': 'Chen Ning Yang',
#   'target': 'Leon Neil Cooper',
#   'value': 0.4178082364212106},
#  {'source': 'Chen Ning Yang',
#   'target': 'Robert B. Laughlin',
#   'value': 0.41568853293932095},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.5217110695571426},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Serge Haroche',
#   'value': 0.5208464606368279},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.505624239095538},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Alfred Kastler',
#   'value': 0.4997121074157477},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'George E. Smith',
#   'value': 0.4900519450524746},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.48953416486229523},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Hugh David Politzer',
#   'value': 0.4776896981957305},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.47735353264743263},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'John M. Kosterlitz',
#   'value': 0.4688711377250483},
#  {'source': 'Claude Cohen-Tannoudji',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.4660515527752662},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Bertram Brockhouse',
#   'value': 0.6256100472286404},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Riccardo Giacconi',
#   'value': 0.5334166853982742},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.5253839644047785},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Robert Hofstadter',
#   'value': 0.5242102751560125},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Eric Allin Cornell',
#   'value': 0.5229663584696977},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'John L. Hall',
#   'value': 0.5215117127859696},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Alexei Alexeyevich Abrikosov',
#   'value': 0.5174868446657552},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Jerome I. Friedman',
#   'value': 0.5122659539788922},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'George E. Smith',
#   'value': 0.5000682977757224},
#  {'source': 'Clifford Glenwood Shull',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.4970034506244115},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Owen Willans Richardson',
#   'value': 0.5357107399633337},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.5273306704778374},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.5193941427714682},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.5080753973397236},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.4998702474947592},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4800116954494889},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4581978122941491},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Andre Geim',
#   'value': 0.45725588760824215},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Takaaki Kajita',
#   'value': 0.4546611071601128},
#  {'source': 'Clinton Joseph Davisson',
#   'target': 'Eric Allin Cornell',
#   'value': 0.45330250806152916},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'F. Duncan M. Haldane',
#   'value': 0.6021337933580945},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Riccardo Giacconi',
#   'value': 0.6015270820515618},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'John M. Kosterlitz',
#   'value': 0.5978699265604385},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5899647787145684},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Eric Allin Cornell',
#   'value': 0.5894737415891883},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Herbert Kroemer',
#   'value': 0.5846685062496231},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.5772503028261194},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'George E. Smith',
#   'value': 0.5737222788444726},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'David J. Thouless',
#   'value': 0.5516934253692246},
#  {'source': 'Daniel Chee Tsui',
#   'target': 'Hugh David Politzer',
#   'value': 0.5453518264745629},
#  {'source': 'David J. Gross',
#   'target': 'Leon Neil Cooper',
#   'value': 0.47405866771816024},
#  {'source': 'David J. Gross',
#   'target': 'Robert Hofstadter',
#   'value': 0.46401884209406363},
#  {'source': 'David J. Gross',
#   'target': 'Tsung-Dao Lee',
#   'value': 0.4543325076022108},
#  {'source': 'David J. Gross',
#   'target': 'John Robert Schrieffer',
#   'value': 0.4503999041112024},
#  {'source': 'David J. Gross',
#   'target': 'James Watson Cronin',
#   'value': 0.4501266932165179},
#  {'source': 'David J. Gross',
#   'target': 'Hiroshi Amano',
#   'value': 0.44711411529837375},
#  {'source': 'David J. Gross',
#   'target': 'David Morris Lee',
#   'value': 0.4432772064846098},
#  {'source': 'David J. Gross',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4401735732170768},
#  {'source': 'David J. Gross',
#   'target': 'Sheldon Lee Glashow',
#   'value': 0.43861342715904195},
#  {'source': 'David J. Gross',
#   'target': 'Murray Gell-Mann',
#   'value': 0.4222520309768718},
#  {'source': 'David J. Thouless',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.6265637673198357},
#  {'source': 'David J. Thouless',
#   'target': 'Andre Geim',
#   'value': 0.5986777837381132},
#  {'source': 'David J. Thouless',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5938906263240523},
#  {'source': 'David J. Thouless',
#   'target': 'François Englert',
#   'value': 0.5904919600788411},
#  {'source': 'David J. Thouless',
#   'target': 'Anthony James Leggett',
#   'value': 0.576717274854699},
#  {'source': 'David J. Thouless',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.5610167447288481},
#  {'source': 'David J. Thouless',
#   'target': 'Martin Lewis Perl',
#   'value': 0.5440953988807155},
#  {'source': 'David J. Thouless',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.5423952525640229},
#  {'source': 'David J. Thouless',
#   'target': 'Robert B. Laughlin',
#   'value': 0.5351037299403866},
#  {'source': 'David J. Thouless',
#   'target': 'Eric Allin Cornell',
#   'value': 0.533272366011252},
#  {'source': 'David J. Wineland',
#   'target': 'Yoichiro Nambu',
#   'value': 0.7586117972593553},
#  {'source': 'David J. Wineland',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.7143063272425411},
#  {'source': 'David J. Wineland',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.6081432496341014},
#  {'source': 'David J. Wineland',
#   'target': 'John Robert Schrieffer',
#   'value': 0.5342869729457352},
#  {'source': 'David J. Wineland',
#   'target': 'Jerome I. Friedman',
#   'value': 0.5304926560075431},
#  {'source': 'David J. Wineland',
#   'target': 'John L. Hall',
#   'value': 0.5257012249836434},
#  {'source': 'David J. Wineland',
#   'target': 'Eugene Paul Wigner',
#   'value': 0.5253141130771458},
#  {'source': 'David J. Wineland',
#   'target': 'David J. Thouless',
#   'value': 0.5056766290289276},
#  {'source': 'David J. Wineland',
#   'target': 'Arthur Leonard Schawlow',
#   'value': 0.49387832686918864},
#  {'source': 'David J. Wineland',
#   'target': 'Edward Mills Purcell',
#   'value': 0.4919148066364784},
#  {'source': 'David Morris Lee',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.7969425124251639},
#  {'source': 'David Morris Lee',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.7672210032028289},
#  {'source': 'David Morris Lee',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.6001656943913696},
#  {'source': 'David Morris Lee',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.5965854349735086},
#  {'source': 'David Morris Lee',
#   'target': 'John M. Kosterlitz',
#   'value': 0.5952491862268516},
#  {'source': 'David Morris Lee',
#   'target': 'David J. Thouless',
#   'value': 0.5800263865563996},
#  {'source': 'David Morris Lee',
#   'target': 'Riccardo Giacconi',
#   'value': 0.5733064923960371},
#  {'source': 'David Morris Lee',
#   'target': 'Hugh David Politzer',
#   'value': 0.564905617369716},
#  {'source': 'David Morris Lee',
#   'target': 'Robert B. Laughlin',
#   'value': 0.5503463931570591},
#  {'source': 'David Morris Lee',
#   'target': 'Richard E. Taylor',
#   'value': 0.53793325358925},
#  {'source': 'Dennis Gabor',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4546273653678743},
#  {'source': 'Dennis Gabor',
#   'target': 'Manne Siegbahn',
#   'value': 0.4542673284612402},
#  {'source': 'Dennis Gabor',
#   'target': 'Andre Geim',
#   'value': 0.45301021582861684},
#  {'source': 'Dennis Gabor',
#   'target': 'Hiroshi Amano',
#   'value': 0.4449295811331851},
#  {'source': 'Dennis Gabor',
#   'target': 'Frits Zernike',
#   'value': 0.440603149333113},
#  {'source': 'Dennis Gabor',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.43709600926928843},
#  {'source': 'Dennis Gabor',
#   'target': 'Theodor W. Hänsch',
#   'value': 0.42507061872036284},
#  {'source': 'Dennis Gabor',
#   'target': 'Anthony James Leggett',
#   'value': 0.42443309274262786},
#  {'source': 'Dennis Gabor',
#   'target': 'Zhores Ivanovich Alferov',
#   'value': 0.4120745705606008},
#  {'source': 'Dennis Gabor',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.4077398543993551},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4209044619350634},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Hiroshi Amano',
#   'value': 0.3978287644048355},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Jerome I. Friedman',
#   'value': 0.3915144641425238},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.39136525125275773},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'David J. Wineland',
#   'value': 0.39022529277952406},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Carl David Anderson',
#   'value': 0.38818255963533266},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Owen Chamberlain',
#   'value': 0.3878209392402806},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Manne Siegbahn',
#   'value': 0.38277677400668786},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Martin Lewis Perl',
#   'value': 0.38030707499462435},
#  {'source': 'Donald Arthur Glaser',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.38030190959618054},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Robert Coleman Richardson',
#   'value': 0.7959218924251643},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.633449110050307},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Eric Allin Cornell',
#   'value': 0.6259913583504028},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.6150239847323237},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'John M. Kosterlitz',
#   'value': 0.6084508993565358},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Riccardo Giacconi',
#   'value': 0.6068486363253319},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'David J. Thouless',
#   'value': 0.6006152060411214},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5978348036713611},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Richard E. Taylor',
#   'value': 0.59777816081164},
#  {'source': 'Douglas D. Osheroff',
#   'target': 'Jerome I. Friedman',
#   'value': 0.5802437305816328},
#  {'source': 'Edward Mills Purcell',
#   'target': 'John Robert Schrieffer',
#   'value': 0.5277880441206545},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Jerome I. Friedman',
#   'value': 0.5237372923717367},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.5186298174273596},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Felix Bloch',
#   'value': 0.5173574620527145},
#  {'source': 'Edward Mills Purcell',
#   'target': 'William Alfred Fowler',
#   'value': 0.4966325642538134},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Percy Williams Bridgman',
#   'value': 0.4939265923608676},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Yoichiro Nambu',
#   'value': 0.47677748520891},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Frederick Reines',
#   'value': 0.4653845788338855},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Burton Richter',
#   'value': 0.45607306824541977},
#  {'source': 'Edward Mills Purcell',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.45364635000552356},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Charles Glover Barkla',
#   'value': 0.36020375626668366},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.3411883536589781},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Manne Siegbahn',
#   'value': 0.32156588838690725},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Andre Geim',
#   'value': 0.3135381191733041},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Edward Mills Purcell',
#   'value': 0.3131539751721016},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.3102815280768938},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Frits Zernike',
#   'value': 0.30358844107589306},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Hiroshi Amano',
#   'value': 0.2979564001061619},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.2978545659003522},
#  {'source': 'Edward Victor Appleton',
#   'target': 'Victor Francis Hess',
#   'value': 0.29689460500173653},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Owen Chamberlain',
#   'value': 0.4659648974164911},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Enrico Fermi',
#   'value': 0.45616101877726395},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Frederick Reines',
#   'value': 0.3911964286384036},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.37223905092635384},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Isidor Isaac Rabi',
#   'value': 0.37059153258767336},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Leo James Rainwater',
#   'value': 0.36980744269221594},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Maria Goeppert-Mayer',
#   'value': 0.35361438637638853},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'James Chadwick',
#   'value': 0.3477861852484385},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Robert Hofstadter',
#   'value': 0.3433606464316523},
#  {'source': 'Emilio Gino Segrè',
#   'target': 'Melvin Schwartz',
#   'value': 0.34314298670395876},
#  {'source': 'Enrico Fermi',
#   'target': 'fermi liquid',
#   'value': 0.49399045371415606},
#  {'source': 'Enrico Fermi',
#   'target': 'fermi gas',
#   'value': 0.4903428968813642},
#  {'source': 'Enrico Fermi',
#   'target': 'Leo James Rainwater',
# ...
#  {'source': 'Ilya Frank',
#   'target': 'Makoto Kobayashi',
#   'value': 0.44888544784309703},
#  {'source': 'Ilya Frank',
#   'target': 'Wolfgang Paul',
#   'value': 0.44573978067061104},
#  {'source': 'Ilya Frank',
#   'target': 'Frits Zernike',
#   'value': 0.43677178341265904},
#  {'source': 'Isamu Akasaki',
#   'target': 'Shuji Nakamura',
#   'value': 0.5407656624719185},
#  {'source': 'Isamu Akasaki',
#   'target': 'Charles K. Kao',
#   'value': 0.526141747331502},
#  {'source': 'Isamu Akasaki',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5046285218804483},
#  {'source': 'Isamu Akasaki',
#   'target': 'Toshihide Maskawa',
#   'value': 0.49491505757791054},
#  {'source': 'Isamu Akasaki',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4886772575554535},
#  {'source': 'Isamu Akasaki',
#   'target': 'John L. Hall',
#   'value': 0.47315576267103737},
#  {'source': 'Isamu Akasaki',
#   'target': 'Herbert Kroemer',
#   'value': 0.46579051461490395},
#  {'source': 'Isamu Akasaki',
#   'target': 'Makoto Kobayashi',
#   'value': 0.46052316008772665},
#  {'source': 'Isamu Akasaki',
#   'target': 'Manne Siegbahn',
#   'value': 0.45861077219079704},
#  {'source': 'Isamu Akasaki',
#   'target': 'Leo Esaki',
#   'value': 0.45497653182321424},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Leo James Rainwater',
#   'value': 0.446354828397928},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4031311105322586},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Melvin Schwartz',
#   'value': 0.3980190974181568},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Aage Bohr',
#   'value': 0.3874841326891968},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Enrico Fermi',
#   'value': 0.3867941503170009},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Hans Albrecht Bethe',
#   'value': 0.38326745845434024},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'John Douglas Cockcroft',
#   'value': 0.3770470431346934},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Jerome I. Friedman',
#   'value': 0.37564128833641663},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Eugene Paul Wigner',
#   'value': 0.37339016015745863},
#  {'source': 'Isidor Isaac Rabi',
#   'target': 'Ernest Lawrence',
#   'value': 0.369227515977673},
#  {'source': 'Ivar Giaever',
#   'target': 'Andre Geim',
#   'value': 0.48438579071197907},
#  {'source': 'Ivar Giaever',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.4568855231735045},
#  {'source': 'Ivar Giaever',
#   'target': 'Toshihide Maskawa',
#   'value': 0.45415710149916827},
#  {'source': 'Ivar Giaever',
#   'target': 'Manne Siegbahn',
#   'value': 0.4492145981073365},
#  {'source': 'Ivar Giaever',
#   'target': 'Takaaki Kajita',
#   'value': 0.44755345125688123},
#  {'source': 'Ivar Giaever',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4448693826758615},
#  {'source': 'Ivar Giaever',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.4436732139070762},
#  {'source': 'Ivar Giaever',
#   'target': 'John L. Hall',
#   'value': 0.4431817156457075},
#  {'source': 'Ivar Giaever',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.4333801965520775},
#  {'source': 'Ivar Giaever',
#   'target': 'Konstantin Novoselov',
#   'value': 0.42936396256156256},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Wolfgang Paul',
#   'value': 0.5053392643648854},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Walther Bothe',
#   'value': 0.48825706153962345},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Werner Heisenberg',
#   'value': 0.4355311812382886},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Johannes Stark',
#   'value': 0.43235780402241686},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.4188833598454333},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Hans Georg Dehmelt',
#   'value': 0.40303415932090186},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Toshihide Maskawa',
#   'value': 0.3960569635953979},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'David J. Gross',
#   'value': 0.3895478713894088},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Maria Goeppert-Mayer',
#   'value': 0.38875615091246485},
#  {'source': 'J. Hans D. Jensen',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.3848636122056747},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'David J. Wineland',
#   'value': 0.7022322227695899},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.6437898730645015},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'Frederick Reines',
#   'value': 0.603187262967521},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'Chen Ning Yang',
#   'value': 0.5685641855433193},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'Herbert Kroemer',
#   'value': 0.4785242034537581},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'Eugene Paul Wigner',
#   'value': 0.4631792470366624},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'Albert Abraham Michelson',
#   'value': 0.4371775089735715},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'Edward Mills Purcell',
#   'value': 0.4300350489945766},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'John L. Hall',
#   'value': 0.41885851531444124},
#  {'source': 'Jack St. Clair Kilby',
#   'target': 'George E. Smith',
#   'value': 0.4142800138668481},
#  {'source': 'Jack Steinberger',
#   'target': 'James Watson Cronin',
#   'value': 0.4593133474938701},
#  {'source': 'Jack Steinberger',
#   'target': 'Raymond Davis, Jr.',
#   'value': 0.41921309765491516},
#  {'source': 'Jack Steinberger',
#   'target': 'Martin Lewis Perl',
#   'value': 0.4070104618370787},
#  {'source': 'Jack Steinberger',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.3966471969335372},
#  {'source': 'Jack Steinberger',
#   'target': 'Frederick Reines',
#   'value': 0.39437675302312236},
#  {'source': 'Jack Steinberger',
#   'target': 'Eric Allin Cornell',
#   'value': 0.385029277280305},
#  {'source': 'Jack Steinberger',
#   'target': 'Toshihide Maskawa',
#   'value': 0.3789702628808841},
#  {'source': 'Jack Steinberger',
#   'target': 'Clifford Glenwood Shull',
#   'value': 0.37829341526773874},
#  {'source': 'Jack Steinberger',
#   'target': 'Leon Neil Cooper',
#   'value': 0.3774138201431322},
#  {'source': 'Jack Steinberger',
#   'target': 'Leo James Rainwater',
#   'value': 0.3749815178810504},
#  {'source': 'James Chadwick',
#   'target': 'John Douglas Cockcroft',
#   'value': 0.46503301959668797},
#  {'source': 'James Chadwick',
#   'target': 'Leo James Rainwater',
#   'value': 0.43620913120963495},
#  {'source': 'James Chadwick',
#   'target': 'Ernest Lawrence',
#   'value': 0.41796632264756234},
#  {'source': 'James Chadwick',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.40071243679169016},
#  {'source': 'James Chadwick',
#   'target': 'Enrico Fermi',
#   'value': 0.39798528762858676},
#  {'source': 'James Chadwick',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.38570751891156063},
#  {'source': 'James Chadwick',
#   'target': 'Aage Bohr',
#   'value': 0.37268844152097225},
#  {'source': 'James Chadwick',
#   'target': 'Isidor Isaac Rabi',
#   'value': 0.3680173238412879},
#  {'source': 'James Chadwick',
#   'target': 'nuclear',
#   'value': 0.3567741634883865},
#  {'source': 'James Chadwick',
#   'target': 'nuclear physics',
#   'value': 0.3567741634883865},
#  {'source': 'James Franck',
#   'target': 'Aage Bohr',
#   'value': 0.45639874601239416},
#  {'source': 'James Franck',
#   'target': 'Gustav Hertz',
#   'value': 0.43143911863120277},
#  {'source': 'James Franck',
#   'target': 'Niels Bohr',
#   'value': 0.40467890132736806},
#  {'source': 'James Franck',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.3993219965488774},
#  {'source': 'James Franck',
#   'target': 'John Douglas Cockcroft',
#   'value': 0.3965379069225836},
#  {'source': 'James Franck',
#   'target': 'Frederick Reines',
#   'value': 0.3955910499700895},
#  {'source': 'James Franck',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.39264429360505543},
#  {'source': 'James Franck',
#   'target': 'Jerome I. Friedman',
#   'value': 0.3913269436629628},
#  {'source': 'James Franck',
#   'target': 'James Chadwick',
#   'value': 0.39101548655464013},
#  {'source': 'James Franck',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.38306630292431526},
#  {'source': 'James Watson Cronin',
#   'target': 'Val Logsdon Fitch',
#   'value': 0.4574442236204919},
#  {'source': 'James Watson Cronin',
#   'target': 'Leo James Rainwater',
#   'value': 0.4496099851249156},
#  {'source': 'James Watson Cronin',
#   'target': 'Robert Hofstadter',
#   'value': 0.44224103051546215},
#  {'source': 'James Watson Cronin',
#   'target': 'Anthony James Leggett',
#   'value': 0.4408133799945393},
#  {'source': 'James Watson Cronin',
#   'target': 'Bertram Brockhouse',
#   'value': 0.4401277714865361},
#  {'source': 'James Watson Cronin',
#   'target': 'Chen Ning Yang',
#   'value': 0.4373315639506892},
#  {'source': 'James Watson Cronin',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.43712360784299725},
#  {'source': 'James Watson Cronin',
#   'target': 'Toshihide Maskawa',
#   'value': 0.4358638815890044},
#  {'source': 'James Watson Cronin',
#   'target': 'Hiroshi Amano',
#   'value': 0.43512609799851215},
#  {'source': 'James Watson Cronin',
#   'target': 'Leon Neil Cooper',
#   'value': 0.4335877321183783},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Gabriel Lippmann',
#   'value': 0.4817268846881546},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Georges Charpak',
#   'value': 0.4621555351561802},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Louis Victor Pierre Raymond, 7th Duc de Broglie',
#   'value': 0.45624868627453813},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.37615819405184003},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Claude Cohen-Tannoudji',
#   'value': 0.3608468695789521},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Hiroshi Amano',
#   'value': 0.35855837915828015},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.35621995677106266},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Manne Siegbahn',
#   'value': 0.34165557023117155},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Bertram Brockhouse',
#   'value': 0.3386601873889356},
#  {'source': 'Jean Baptiste Perrin',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.337409558808762},
#  {'source': 'Jerome I. Friedman',
#   'target': 'Burton Richter',
#   'value': 0.5669402216478681},
#  {'source': 'Jerome I. Friedman',
#   'target': 'Robert B. Laughlin',
#   'value': 0.5468708996366681},
#  {'source': 'Jerome I. Friedman',
#   'target': 'Horst Ludwig Störmer',
#   'value': 0.5328839556055323},
#  {'source': 'Jerome I. Friedman',
#   'target': 'Bertram Brockhouse',
#   'value': 0.5285829184174656},
#  {'source': 'Jerome I. Friedman',
#   'target': 'Norman Foster Ramsey',
#   'value': 0.515056715582686},
#  {'source': 'Jerome I. Friedman',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.509659104707256},
#  {'source': 'Jerome I. Friedman',
#   'target': 'Kai Manne Börje Siegbahn',
#   'value': 0.508669838792128},
#  {'source': 'Jerome I. Friedman',
#   'target': 'David J. Thouless',
#   'value': 0.5068115964312191},
#  {'source': 'Jerome I. Friedman',
#   'target': 'George E. Smith',
#   'value': 0.5046311172822161},
#  {'source': 'Jerome I. Friedman',
#   'target': 'Arthur Leonard Schawlow',
#   'value': 0.4858054117796009},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Johannes Stark',
#   'value': 0.41910395089484753},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Wilhelm Wien',
#   'value': 0.3460985647465289},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Hiroshi Amano',
#   'value': 0.27685530684054677},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Toshihide Maskawa',
#   'value': 0.273215906341693},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Manne Siegbahn',
#   'value': 0.2697010468411183},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'J. Hans D. Jensen',
#   'value': 0.25767594780504843},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Owen Willans Richardson',
#   'value': 0.2529016241163795},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Nicolay Gennadiyevich Basov',
#   'value': 0.25284997426178923},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Albert Fert',
#   'value': 0.25133266697508694},
#  {'source': 'Johannes Diderik van der Waals',
#   'target': 'Werner Heisenberg',
#   'value': 0.2507628843911811},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Karl Alexander Müller',
#   'value': 0.6593545186918207},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Manne Siegbahn',
#   'value': 0.490301253736031},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.48339985232816307},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Frits Zernike',
#   'value': 0.4666122101525883},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Pierre-Gilles de Gennes',
#   'value': 0.464106292512872},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'David Morris Lee',
#   'value': 0.4634418492850561},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Riccardo Giacconi',
#   'value': 0.4620686860544392},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.44766628098893685},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Hans Georg Dehmelt',
#   'value': 0.4429052331249465},
#  {'source': 'Johannes Georg Bednorz',
#   'target': 'Theodor W. Hänsch',
#   'value': 0.4376375822561222},
#  {'source': 'Johannes Stark',
#   'target': 'Wilhelm Wien',
#   'value': 0.47496995880250703},
#  {'source': 'Johannes Stark',
#   'target': 'Werner Heisenberg',
#   'value': 0.44285706823578275},
#  {'source': 'Johannes Stark',
#   'target': 'Simon van der Meer',
#   'value': 0.42297130303811104},
#  {'source': 'Johannes Stark',
#   'target': 'Philipp Eduard Anton von Lenard',
#   'value': 0.40424297421075683},
#  {'source': 'Johannes Stark',
#   'target': 'Frits Zernike',
#   'value': 0.3693676869141758},
#  {'source': 'Johannes Stark',
#   'target': 'Hiroshi Amano',
#   'value': 0.3556683188651173},
#  {'source': 'Johannes Stark',
#   'target': 'James Franck',
#   'value': 0.3511717932880482},
#  {'source': 'Johannes Stark',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.3505983962693385},
#  {'source': 'Johannes Stark',
#   'target': 'Ben Roy Mottelson',
#   'value': 0.3487581596375766},
#  {'source': 'Johannes Stark',
#   'target': 'Nicolaas Bloembergen',
#   'value': 0.3482766621542806},
#  {'source': 'John Bardeen',
#   'target': 'Walter Houser Brattain',
#   'value': 0.5939141339002018},
#  {'source': 'John Bardeen',
#   'target': 'Jack St. Clair Kilby',
#   'value': 0.45210398647641054},
#  {'source': 'John Bardeen',
#   'target': 'Frederick Reines',
#   'value': 0.43929150178942084},
#  {'source': 'John Bardeen',
#   'target': 'John Hasbrouck Van Vleck',
#   'value': 0.4383498089762288},
#  {'source': 'John Bardeen',
#   'target': 'John C. Mather',
#   'value': 0.4279836688973597},
#  {'source': 'John Bardeen',
#   'target': 'Jerome I. Friedman',
#   'value': 0.4254820331185345},
#  {'source': 'John Bardeen',
#   'target': 'Edward Mills Purcell',
#   'value': 0.42399582705503724},
#  {'source': 'John Bardeen',
#   'target': 'Charles Hard Townes',
#   'value': 0.42329541798689363},
#  {'source': 'John Bardeen',
#   'target': 'Leon Neil Cooper',
#   'value': 0.4219043288969407},
#  {'source': 'John Bardeen',
#   'target': 'Anthony James Leggett',
#   'value': 0.421363342032535},
#  {'source': 'John C. Mather',
#   'target': 'George F. Smoot',
#   'value': 0.5216111259925374},
#  {'source': 'John C. Mather',
#   'target': 'John L. Hall',
#   'value': 0.4847928499512922},
#  {'source': 'John C. Mather',
#   'target': 'Riccardo Giacconi',
#   'value': 0.47714129514227444},
#  {'source': 'John C. Mather',
#   'target': 'David J. Wineland',
#   'value': 0.4342736673046447},
#  {'source': 'John C. Mather',
#   'target': 'John Robert Schrieffer',
#   'value': 0.425133341560498},
#  {'source': 'John C. Mather',
#   'target': 'Masatoshi Koshiba',
#   'value': 0.4223861159239023},
#  {'source': 'John C. Mather',
#   'target': 'Yoichiro Nambu',
#   'value': 0.4084547580100231},
#  {'source': 'John C. Mather',
#   'target': 'Jerome I. Friedman',
#   'value': 0.4056127602909235},
#  {'source': 'John C. Mather',
#   'target': 'Daniel Chee Tsui',
#   'value': 0.4054751494023501},
#  {'source': 'John C. Mather',
#   'target': 'Douglas D. Osheroff',
#   'value': 0.4033142064548536},
#  ...]

# %% [markdown]
# We now create the final dictionary for the network and save it into a json file

# %%
import json
network_dict = {"nodes": nodes_list,
                "links": links_list}

with open("./data/physicists.json","w") as f:
    json.dump(network_dict, f, indent=4)

# %% [markdown]
# If you have a mac, the following script is going to open a safari window to visualize this network, otherwise you can just open the index.html file with Safari or Firefox. For some reason it does not work with chrome.

# %%
import os
os.system("open -a /Applications/Safari.app ./index.html")
# Out:
# 256

# %% [markdown]
# Adjust the parameters to try to find nodes that tend to be grouped together. You can try to recreate the network with with different number of links.
